# %% [markdown]
# #ENV

# %%
QA_PATH = '/content/drive/MyDrive/ABC/KnowGPT/train_rand_split.jsonl'
CONCEPTNET_PATH = '/content/drive/MyDrive/ABC/KnowGPT/conceptnet_en.csv'
PKL_CCN_PATH = lambda sample: f'/content/drive/MyDrive/ABC/KnowGPT/ccn_samples_{sample}.pkl'
ENTITY_TO_VEC_PATH = f'/content/drive/MyDrive/ABC/KnowGPT/entity_to_vec.pkl'
TRIPLE_TO_VEC_PATH = f'/content/drive/MyDrive/ABC/KnowGPT/triple_to_vec.pkl'

# %%
EXTRACTED_TRAIN_PATH = '/content/drive/MyDrive/ABC/KnowGPT/extracted_train_paths_v3.pkl'

# %%
MAB_TRAIN_PATH = '/content/drive/MyDrive/ABC/KnowGPT/mab_train_paths_v3.pkl'

# %%
RESULT_TRAIN_PATH = f'/content/drive/MyDrive/ABC/KnowGPT/mab_training_log_v3.csv'

# %% [markdown]
# # DATA

# %% [markdown]
# ---
#
#
# 1. Load ConceptNet
#
#
# ---

# %%
import pandas as pd

class ConceptNet:
    def __init__(self, path: str, max_edges: int = None):
        """
        Initialize a ConceptNet object.

        Args:
            path (str): Path to the ConceptNet CSV/TSV file.
            max_edges (int, optional): Maximum number of edges to load. Defaults to None (load all).
        """
        self.path = path
        self.max_edges = max_edges
        self.df = None  # DataFrame to hold processed edges

    def load(self):
        """
        Load and preprocess ConceptNet data.
        Keeps only English-language edges and extracts (relation, head, tail) triples.
        """
        df = pd.read_csv(self.path, sep='\t', header=None, usecols=[1, 2, 3],
                         names=['relation', 'start', 'end'],
                         engine='c', on_bad_lines='skip')

        # Keep only English-language edges
        df = df[df['start'].str.startswith('/c/en/') & df['end'].str.startswith('/c/en/')]

        # Extract clean concept names and relation names
        df['head'] = df['start'].str.extract(r'^/c/en/([^/]+)')[0].str.replace('_', ' ', regex=False)
        df['tail'] = df['end'].str.extract(r'^/c/en/([^/]+)')[0].str.replace('_', ' ', regex=False)
        df['relation'] = df['relation'].str.extract(r'^/r/([^/]+)')[0]

        # Limit the number of edges if max_edges is specified
        if self.max_edges:
            df = df.sample(n=self.max_edges, random_state=42)

        self.df = df[['relation', 'head', 'tail']]
        return self.df

    def get_edges(self):
        """
        Return the preprocessed DataFrame of edges.

        Returns:
            pd.DataFrame: DataFrame with columns ['relation', 'head', 'tail']
        """
        if self.df is None:
            raise ValueError("You must call .load() before accessing edges.")
        return self.df

    def get_triples(self):
        """
        Return the triples as a list of (head, relation, tail) tuples.

        Returns:
            List[Tuple[str, str, str]]: List of triples.
        """
        if self.df is None:
            raise ValueError("You must call .load() before accessing triples.")
        return list(self.df.itertuples(index=False, name=None))

# %%
import pandas as pd
import networkx as nx
import numpy as np
from typing import Dict, List, Tuple
from sentence_transformers import SentenceTransformer

class ConceptNetGraphBuilder:
    def __init__(self, triples: pd.DataFrame):
        """
        Initialize the graph builder with a DataFrame of ConceptNet triples.

        Args:
            triples (pd.DataFrame): DataFrame with columns ['relation', 'head', 'tail']
        """
        required_cols = {'relation', 'head', 'tail'}
        if not required_cols.issubset(triples.columns):
            raise ValueError("DataFrame must contain columns: 'relation', 'head', 'tail'")

        self.triples = triples
        self.graph = nx.MultiDiGraph()  # Directed multigraph to support multiple relations

    def build_graph(self):
        """
        Build the directed multigraph from ConceptNet triples.
        Each edge is labeled with the relation type.
        """
        for _, row in self.triples.iterrows():
            head, relation, tail = row['head'], row['relation'], row['tail']
            self.graph.add_edge(head, tail, relation=relation)
        return self.graph

    def get_neighbors(self, node):
        """
        Get all direct neighbors of a node.
        """
        return list(self.graph.neighbors(node))

    def get_relation(self, source, target):
        """
        Get all relations between two nodes.
        """
        if self.graph.has_edge(source, target):
            return [data['relation'] for data in self.graph.get_edge_data(source, target).values()]
        else:
            return []

    def shortest_path(self, source, target):
        """
        Get the shortest path (sequence of nodes) between two concepts.
        """
        try:
            return nx.shortest_path(self.graph, source=source, target=target)
        except nx.NetworkXNoPath:
            return []

    def get_graph(self):
        """
        Return the internal NetworkX graph.
        """
        return self.graph

    def build_entity_embeddings(self, model_name='all-MiniLM-L6-v2', batch_size=256) -> Dict[str, np.ndarray]:
        """
        Generate sentence embeddings for all nodes in the graph.

        Returns:
            dict: A dictionary {entity: embedding_vector}
        """
        print(f"🔠 Encoding {self.graph.number_of_nodes():,} nodes using model '{model_name}'")
        model = SentenceTransformer(model_name)
        nodes = list(self.graph.nodes)
        embeddings = model.encode(nodes, batch_size=batch_size, show_progress_bar=True)
        return {node: vec for node, vec in zip(nodes, embeddings)}

    def build_triple_embeddings(self, model_name='all-MiniLM-L6-v2', batch_size=256, use_special_tokens=False) -> Dict[Tuple[str, str, str], np.ndarray]:
        """
        Generate sentence embeddings for all (head, relation, tail) triples.

        Args:
            model_name (str): Name of the SentenceTransformer model.
            batch_size (int): Batch size for encoding.
            use_special_tokens (bool): Whether to use [H], [R], [T] format.

        Returns:
            dict: A dictionary {(head, relation, tail): embedding_vector}
        """
        print(f"🧠 Encoding {len(self.triples):,} triples using model '{model_name}'")
        model = SentenceTransformer(model_name)
        triples = list(self.triples.itertuples(index=False, name=None))  # (relation, head, tail)

        if use_special_tokens:
            texts = [f"[H] {h} [R] {r} [T] {t}" for r, h, t in triples]
        else:
            texts = [f"{h} {r} {t}" for r, h, t in triples]

        embeddings = model.encode(texts, batch_size=batch_size, show_progress_bar=True)
        return {(h, r, t): vec for (r, h, t), vec in zip(triples, embeddings)}

# %%
import os
import pandas as pd  # Đừng quên import nếu dùng bên ngoài notebook

def load_or_cache_conceptnet(path, sample_size=None, cache_path=None):
    """
    Load ConceptNet from cache if available, otherwise process and save it.

    Args:
        path (str): Path to the raw ConceptNet CSV file.
        sample_size (int or None): Number of edges to sample, or None for full dataset.
        cache_path (str): Path to save or load the cached DataFrame.

    Returns:
        pd.DataFrame: Processed ConceptNet triples (relation, head, tail).
    """
    if os.path.exists(cache_path):
        print(f"🔄 Loading from cache: {cache_path}")
        return pd.read_pickle(cache_path)
    else:
        print(f"📥 Loading and processing raw ConceptNet...")
        cn = ConceptNet(path, max_edges=sample_size)
        df = cn.load()
        df.to_pickle(cache_path)
        print(f"✅ Saved cache to: {cache_path}")
        return df

# %%
# Set paths
sample_size = None  # a number or None for full
csv_path = CONCEPTNET_PATH
cache_path = PKL_CCN_PATH(sample_size)  # Define this function separately

# Step 1: Load or cache
df = load_or_cache_conceptnet(csv_path, sample_size, cache_path)
print(f"✅ Loaded {len(df)} edges")

# Step 2: Build the graph
builder = ConceptNetGraphBuilder(df)
KG = builder.build_graph()
print(f"✅ Graph built: {KG.number_of_nodes()} nodes, {KG.number_of_edges()} edges")

# Step 3: Vectorize the graph

# Option 1: Encode node (entity) embeddings
entity_vecs = builder.build_entity_embeddings()

# Option 2: Encode triple (path-based) embeddings
triple_vecs = builder.build_triple_embeddings(use_special_tokens=True)
# Out:
# 🔄 Loading from cache: /content/drive/MyDrive/ABC/KnowGPT/ccn_samples_None.pkl
# ✅ Loaded 3423004 edges
# ✅ Graph built: 1165190 nodes, 3423004 edges
# 🔠 Encoding 1,165,190 nodes using model 'all-MiniLM-L6-v2'
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/4552 [00:00<?, ?it/s]
# 🧠 Encoding 3,423,004 triples using model 'all-MiniLM-L6-v2'
# Batches:   0%|          | 0/13372 [00:00<?, ?it/s]

# %%
# Save:
import pickle
with open(ENTITY_TO_VEC_PATH, "wb") as f:
    pickle.dump(entity_vecs, f)

with open(TRIPLE_TO_VEC_PATH, "wb") as f:
    pickle.dump(triple_vecs, f)

# %%
# Read
import pickle

with open(ENTITY_TO_VEC_PATH, "rb") as f:
    entity_to_vec = pickle.load(f)

with open(TRIPLE_TO_VEC_PATH, "rb") as f:
    triplet_to_vec = pickle.load(f)

# %% [markdown]
# ---
# 4. Load Q&A
#
#
# ---

# %%
import json
from typing import List, Dict

class CommonsenseQA:
    def __init__(self, filepath: str):
        """
        Load and parse CommonsenseQA dataset from a .jsonl file.

        Args:
            filepath (str): Path to the CommonsenseQA file (in JSONL format).
        """
        self.filepath = filepath
        self.samples = self._load()

    def _load(self) -> List[Dict]:
        """
        Internal method to load and parse the dataset.

        Returns:
            List[Dict]: List of parsed question samples.
        """
        samples = []
        with open(self.filepath, 'r', encoding='utf-8') as f:
            for line in f:
                entry = json.loads(line)
                q = entry['question']
                answer_label = entry['answerKey']
                answer_text = next(c['text'] for c in q['choices'] if c['label'] == answer_label)

                samples.append({
                    "question_id": entry['id'],
                    "question_text": q['stem'],
                    "options": [c['text'] for c in q['choices']],
                    "correct_answer": answer_text,
                    "correct_answer_label": answer_label,
                    "source_entities": [q['question_concept'].lower()],
                    "target_entity": answer_text.lower()
                })
        return samples

    def get_all(self) -> List[Dict]:
        """
        Return all parsed question samples.

        Returns:
            List[Dict]: All question dictionaries.
        """
        return self.samples

    def get_question_by_id(self, question_id: str) -> Dict:
        """
        Retrieve a question sample by its ID.

        Args:
            question_id (str): ID of the question.

        Returns:
            Dict: The corresponding sample.
        """
        return next((s for s in self.samples if s['question_id'] == question_id), None)

    def get_source_target_pairs(self) -> List[Dict[str, str]]:
        """
        Extract (source_entity, target_entity) pairs for all questions.

        Returns:
            List[Dict[str, str]]: List of source-target pairs.
        """
        return [
            {"source": s["source_entities"][0], "target": s["target_entity"]}
            for s in self.samples
        ]

# %%
# Load dataset
csqa = CommonsenseQA(QA_PATH)

# Get all samples
samples = csqa.get_all()
print(samples[0])

# Get question by ID
# q = csqa.get_question_by_id("075e483d21c29a511267ef62bedc0461")
# print(q["question_text"], q["correct_answer"])

# Get source-target entities for KG linking
entity_pairs = csqa.get_source_target_pairs()
print(entity_pairs[:5])
# Out:
# {'question_id': '075e483d21c29a511267ef62bedc0461', 'question_text': 'The sanctions against the school were a punishing blow, and they seemed to what the efforts the school had made to change?', 'options': ['ignore', 'enforce', 'authoritarian', 'yell at', 'avoid'], 'correct_answer': 'ignore', 'correct_answer_label': 'A', 'source_entities': ['punishing'], 'target_entity': 'ignore'}
# [{'source': 'punishing', 'target': 'ignore'}, {'source': 'people', 'target': 'populated areas'}, {'source': 'choker', 'target': 'jewelry store'}, {'source': 'highway', 'target': 'atlas'}, {'source': 'fox', 'target': 'natural habitat'}]

# %%
# print(len(samples))
# Out:
# 9741

# %% [markdown]
# # Sample of Input Dataset

# %%
print(f"Graph: {len(KG.nodes)} nodes, {len(KG.edges)} edges")

sample_node = list(KG.nodes)[0]
print("📌 Sample node:", sample_node)
print("📌 Neighbors:", list(KG[sample_node])[:5])
print("📌 Edge attributes:", list(KG[sample_node].items())[:1])
# Out:
# Graph: 1165190 nodes, 3423004 edges
# 📌 Sample node: 0
# 📌 Neighbors: ['1', 'empty set', 'first limit ordinal', 'number zero', 'internet slang']
# 📌 Edge attributes: [('1', AtlasView({0: {'relation': 'Antonym'}, 1: {'relation': 'RelatedTo'}}))]

# %%
print(f"Samples: {len(samples)} total")

sample_sample = samples[0]
print("📌 Sample:")
for k, v in sample_sample.items():
    print(f"  {k}: {v}")
# Out:
# Samples: 9741 total
# 📌 Sample:
#   question_id: 075e483d21c29a511267ef62bedc0461
#   question_text: The sanctions against the school were a punishing blow, and they seemed to what the efforts the school had made to change?
#   options: ['ignore', 'enforce', 'authoritarian', 'yell at', 'avoid']
#   correct_answer: ignore
#   correct_answer_label: A
#   source_entities: ['punishing']
#   target_entity: ignore

# %%
print(f"entity_to_vec: {len(entity_to_vec)} entities")

key = list(entity_to_vec.keys())[100]
print("📌 Sample entity:", key)
print("📌 Embedding shape:", entity_to_vec[key].shape)
print("📌 First 5 values:", entity_to_vec[key][:5])
# Out:
# entity_to_vec: 1165190 entities
# 📌 Sample entity: below fold
# 📌 Embedding shape: (384,)
# 📌 First 5 values: [-0.0381018   0.06029986 -0.02394235  0.01007081 -0.0171747 ]

# %%
print(f"triple_to_vec: {len(triplet_to_vec)} entities")

key = list(triplet_to_vec.keys())[100]
print("📌 Sample entity:", key)
print("📌 Embedding shape:", triplet_to_vec[key].shape)
print("📌 First 5 values:", triplet_to_vec[key][:5])

for k in list(triplet_to_vec.keys())[:5]:
    print(k)
# Out:
# triple_to_vec: 3323303 entities
# 📌 Sample entity: ('abstract method', 'Antonym', 'concrete method')
# 📌 Embedding shape: (384,)
# 📌 First 5 values: [-0.07401326  0.06351868  0.01880849 -0.01492029 -0.05005705]
# ('0', 'Antonym', '1')
# ('12 hour clock', 'Antonym', '24 hour clock')
# ('24 hour clock', 'Antonym', '12 hour clock')
# ('5', 'Antonym', '3')
# ('a.c', 'Antonym', 'd.c')

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# # Model

# %%
import random
import numpy as np
import networkx as nx
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer

class KGEnvRL:
    def __init__(self, graph, samples, entity_to_vec=None, triplet_to_vec=None,
                 embed_model: SentenceTransformer = None,
                 max_steps=10, lambda_context=0.5, lambda_concise=0.3,
                 use_triple_embedding=False):
        """
        Environment for KG path reasoning with RL.

        Args:
            graph: NetworkX MultiDiGraph representing the KG.
            samples: List of question samples (each with source_entities, target_entity, question_text).
            entity_to_vec: Dict mapping entity → vector (optional).
            triplet_to_vec: Dict mapping (h, r, t) or [H]h[R]r[T]t → vector (optional).
            embed_model: SentenceTransformer model (fallback if no embedding dict).
            max_steps: Max steps per episode.
            lambda_context: Weight for context-relatedness reward.
            lambda_concise: Weight for conciseness reward.
            use_triple_embedding: Whether to use triple-level embedding.
        """
        self.graph = graph
        self.samples = samples
        self.entity_to_vec = entity_to_vec
        self.triplet_to_vec = triplet_to_vec
        self.embed_model = embed_model
        self.max_steps = max_steps
        self.lambda_context = lambda_context
        self.lambda_concise = lambda_concise
        self.use_triple_embedding = use_triple_embedding

    def reset(self, fixed_sample=False):
        if fixed_sample:
            assert hasattr(self, "sample"), "Must set `env.sample = sample` before reset(fixed_sample=True)"
            self.source = self.sample['source_entities'][0].lower()
            self.target = self.sample['target_entity'].lower()
        else:
            for _ in range(50):  # Avoid infinite loop
                candidate = random.choice(self.samples)
                src = candidate['source_entities'][0].lower()
                tgt = candidate['target_entity'].lower()
                if src in self.graph and tgt in self.graph:
                    try:
                        nx.shortest_path(self.graph, src, tgt)
                        self.sample = candidate
                        self.source = src
                        self.target = tgt
                        break
                    except nx.NetworkXNoPath:
                        continue

        self.current = self.source
        self.steps = 0
        self.path = [self.current]
        self.context_embedding = self.embed_model.encode(self.sample['question_text'])

        return self._get_state()

    def _get_state(self):
        if self.use_triple_embedding:
            # create pseudo triple (cur, ?, target)
            if self.graph.has_edge(self.current, self.target):
                rel_data = self.graph.get_edge_data(self.current, self.target)
                relation = rel_data[list(rel_data.keys())[0]]['relation']
            else:
                relation = "relatedTo"

            triple = (self.current, relation, self.target)
            if self.triplet_to_vec:
                return self.triplet_to_vec.get(triple, np.zeros(768))
            else:
                triple_str = f"[H] {self.current} [R] {relation} [T] {self.target}"
                return self.embed_model.encode(triple_str)
        else:
            e_cur = self.entity_to_vec.get(self.current, np.zeros(384))
            e_tgt = self.entity_to_vec.get(self.target, np.zeros(384))
            return np.concatenate([e_cur, e_tgt - e_cur])  # shape = (768,)

    def _get_path_embedding(self):
        if self.use_triple_embedding:
            triple_vecs = []
            for i in range(len(self.path) - 1):
                h, t = self.path[i], self.path[i + 1]
                if self.graph.has_edge(h, t):
                    rel_data = self.graph.get_edge_data(h, t)
                    relation = rel_data[list(rel_data.keys())[0]]['relation']
                    triple_str = f"[H] {h} [R] {relation} [T] {t}"
                    if self.triplet_to_vec:
                        vec = self.triplet_to_vec.get(triple_str, np.zeros(384))
                    else:
                        vec = self.embed_model.encode(triple_str)
                    triple_vecs.append(vec)
            return np.mean(triple_vecs, axis=0) if triple_vecs else np.zeros(384)
        else:
            node_vecs = [self.entity_to_vec.get(e, np.zeros(384)) for e in self.path]
            return np.mean(node_vecs, axis=0)

    def get_actions(self):
        return list(self.graph[self.current]) if self.current in self.graph else []

    def step(self, action):
        if action not in self.get_actions():
            return self._get_state(), -1.0, True, {"msg": "Invalid action"}

        self.current = action
        self.steps += 1
        self.path.append(self.current)

        done = self.current == self.target or self.steps >= self.max_steps

        # === Compute rewards ===
        r_reach = 1.0 if self.current == self.target else 0.0
        r_context = cosine_similarity(
            self._get_path_embedding().reshape(1, -1),
            self.context_embedding.reshape(1, -1)
        )[0][0]
        r_concise = 1.0 / len(self.path)

        reward = r_reach + self.lambda_context * r_context + self.lambda_concise * r_concise

        return self._get_state(), reward, done, {
            "r_reach": r_reach,
            "r_context": r_context,
            "r_concise": r_concise,
            "path": list(self.path),
            "done": done
        }

    def render(self):
        print(f"[Step {self.steps}] Current: {self.current}, Target: {self.target}")
        print("→ Path so far:", " → ".join(self.path))

# %%
import torch
import torch.nn as nn

class PolicyNet(nn.Module):
    def __init__(self, input_dim=1152, hidden_dim=256):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, 1)  # score for each action
        )

    def forward(self, state, action_vecs):
        """
        Args:
            state: [B, 768]
            action_vecs: [B, N, 384]

        Returns:
            logits: [B, N] (score for each candidate action)
        """
        B, N, _ = action_vecs.shape
        state_expanded = state.unsqueeze(1).expand(-1, N, -1)  # [B, N, 768]
        x = torch.cat([state_expanded, action_vecs], dim=-1)   # [B, N, 1152]
        logits = self.net(x).squeeze(-1)                       # [B, N]
        return logits


class TriplePolicyNet(nn.Module):
    def __init__(self, triple_dim=384, hidden_dim=256):
        super(TriplePolicyNet, self).__init__()
        self.fc1 = nn.Linear(triple_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, 1)  # Output a score per triple

    def forward(self, state, triple_vecs):  # state: [1, D]; triple_vecs: [1, N, triple_dim]
        # Ignore state since we only use triple embedding
        x = triple_vecs.squeeze(0)  # [N, triple_dim]
        x = torch.relu(self.fc1(x))  # [N, hidden_dim]
        scores = self.fc2(x).squeeze(-1)  # [N]
        return scores.unsqueeze(0)  # Return shape [1, N] for consistency

# %%
def train_rl_multi_epoch(policy_net, env, samples,
                         num_epochs=5, repeats_per_sample=3,
                         gamma=0.99, use_triple=False,
                         triplet_to_vec=None, entity_to_vec=None,
                         print_every=1):

    optimizer = torch.optim.Adam(policy_net.parameters(), lr=1e-3)
    all_results = []

    for epoch in range(1, num_epochs + 1):
        print(f"\n🌍 === EPOCH {epoch}/{num_epochs} ===")

        for idx, sample in enumerate(samples):
            env.sample = sample  # fix sample
            paths_for_sample = []

            for repeat in range(repeats_per_sample):
                state = env.reset(fixed_sample=True)
                log_probs, rewards = [], []

                for step in range(env.max_steps):
                    actions = env.get_actions()
                    if not actions:
                        break

                    # === Embedding triple or entity ===
                    if use_triple:
                        triple_candidates = []
                        for t in actions:
                            if env.graph.has_edge(env.current, t):
                                for edge_key in env.graph.get_edge_data(env.current, t):
                                    r = env.graph[env.current][t][edge_key]['relation']
                                    triple_candidates.append((env.current, r, t))
                        if not triple_candidates:
                            break

                        triple_vecs = np.array([
                            triplet_to_vec.get(tri, np.zeros(768)) for tri in triple_candidates
                        ])
                        triple_vecs = torch.tensor(triple_vecs, dtype=torch.float32).unsqueeze(0)
                        state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0)
                        logits = policy_net(state_tensor, triple_vecs)
                        probs = torch.softmax(logits, dim=-1)
                    else:
                        action_vecs = np.array([entity_to_vec.get(a, np.zeros(384)) for a in actions])
                        action_vecs = torch.tensor(action_vecs, dtype=torch.float32).unsqueeze(0)
                        state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0)
                        logits = policy_net(state_tensor, action_vecs)
                        probs = torch.softmax(logits, dim=-1)

                    if torch.isnan(probs).any() or torch.isinf(probs).any():
                        break

                    m = torch.distributions.Categorical(probs)
                    action_idx = m.sample()
                    log_prob = m.log_prob(action_idx)

                    if use_triple:
                        _, _, next_node = triple_candidates[action_idx.item()]
                    else:
                        next_node = actions[action_idx.item()]

                    next_state, reward, done, info = env.step(next_node)
                    log_probs.append(log_prob)
                    rewards.append(reward)
                    state = next_state

                    if done:
                        break

                # === REINFORCE update ===
                returns, R = [], 0
                for r in reversed(rewards):
                    R = r + gamma * R
                    returns.insert(0, R)

                if not returns:
                    continue

                returns = torch.tensor(returns)
                if len(returns) > 1:
                    returns = (returns - returns.mean()) / (returns.std() + 1e-8)

                log_probs = torch.stack(log_probs)
                loss = - (log_probs * returns).sum()

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                if done and reward > 0:
                    paths_for_sample.append({
                        "epoch": epoch,
                        "question_id": sample["question_id"],
                        "question_text": sample["question_text"],
                        "source": sample["source_entities"][0],
                        "target": sample["target_entity"],
                        "path": env.path.copy(),
                        "reward": float(sum(rewards)),
                        "steps": len(env.path),
                    })

                if repeat % print_every == 0:
                    print(f"🧪 Epoch {epoch} | Sample {idx+1}/{len(samples)} | Repeat {repeat+1}/{repeats_per_sample} | Reward: {sum(rewards):.3f} | Path: {' → '.join(env.path)}")

            all_results.extend(paths_for_sample)

    return all_results

# %%
import pickle
import torch
from sentence_transformers import SentenceTransformer

# === Parameters ===
USE_TRIPLE_POLICY = True  # Set to False for entity-level policy
EMBEDDING_DIM = 384
HIDDEN_DIM = 256
NUM_EPOCHS = 5
REPEATS_PER_SAMPLE = 3
MODEL_NAME = "all-MiniLM-L6-v2"

# === Load SentenceTransformer ===
model = SentenceTransformer(MODEL_NAME)

# === Load embeddings ===
if USE_TRIPLE_POLICY:
    entity_to_vec = None
    with open(TRIPLE_TO_VEC_PATH, "rb") as f:
        triplet_to_vec = pickle.load(f)
else:
    triplet_to_vec = None
    with open(ENTITY_TO_VEC_PATH, "rb") as f:
        entity_to_vec = pickle.load(f)

# === Initialize environment ===
env = KGEnvRL(
    graph=KG,  # assumed preloaded NetworkX graph
    samples=samples,  # assumed preloaded sample list
    entity_to_vec=entity_to_vec,
    triplet_to_vec=triplet_to_vec,
    embed_model=model,
    max_steps=10,
    lambda_context=0.7,
    lambda_concise=0.3,
    use_triple_embedding=USE_TRIPLE_POLICY
)

# === Define and train policy ===
if USE_TRIPLE_POLICY:
    policy_net = TriplePolicyNet(triple_dim=EMBEDDING_DIM, hidden_dim=HIDDEN_DIM)
    results = train_rl_multi_epoch(
        policy_net=policy_net,
        env=env,
        samples=samples,
        num_epochs=NUM_EPOCHS,
        repeats_per_sample=REPEATS_PER_SAMPLE,
        use_triple=True,
        triplet_to_vec=triplet_to_vec
    )
else:
    policy_net = PolicyNet(input_dim=EMBEDDING_DIM * 3, hidden_dim=HIDDEN_DIM)
    results = train_rl_multi_epoch(
        policy_net=policy_net,
        env=env,
        samples=samples,
        num_epochs=NUM_EPOCHS,
        repeats_per_sample=REPEATS_PER_SAMPLE,
        use_triple=False,
        entity_to_vec=entity_to_vec
    )
# Out:
# Streaming output truncated to the last 5000 lines.
# 🧪 Epoch 5 | Sample 8076/9741 | Repeat 1/3 | Reward: 0.150 | Path: skyscraper → making offices use less groundspace
# 🧪 Epoch 5 | Sample 8076/9741 | Repeat 2/3 | Reward: 0.150 | Path: skyscraper → making offices use less groundspace
# 🧪 Epoch 5 | Sample 8076/9741 | Repeat 3/3 | Reward: 0.150 | Path: skyscraper → making offices use less groundspace
# 🧪 Epoch 5 | Sample 8077/9741 | Repeat 1/3 | Reward: 0.150 | Path: edge → cutting surface
# 🧪 Epoch 5 | Sample 8077/9741 | Repeat 2/3 | Reward: 0.150 | Path: edge → cutting surface
# 🧪 Epoch 5 | Sample 8077/9741 | Repeat 3/3 | Reward: 0.150 | Path: edge → cutting surface
# 🧪 Epoch 5 | Sample 8078/9741 | Repeat 1/3 | Reward: 0.150 | Path: marmoset → cage at zoo
# 🧪 Epoch 5 | Sample 8078/9741 | Repeat 2/3 | Reward: 0.150 | Path: marmoset → cage at zoo
# 🧪 Epoch 5 | Sample 8078/9741 | Repeat 3/3 | Reward: 0.150 | Path: marmoset → cage at zoo
# 🧪 Epoch 5 | Sample 8079/9741 | Repeat 1/3 | Reward: 0.150 | Path: cemetery → place to go to meditate
# 🧪 Epoch 5 | Sample 8079/9741 | Repeat 2/3 | Reward: 0.150 | Path: cemetery → place to go to meditate
# 🧪 Epoch 5 | Sample 8079/9741 | Repeat 3/3 | Reward: 0.150 | Path: cemetery → place to go to meditate
# 🧪 Epoch 5 | Sample 8080/9741 | Repeat 1/3 | Reward: 0.150 | Path: marble → playing games on ground
# 🧪 Epoch 5 | Sample 8080/9741 | Repeat 2/3 | Reward: 0.150 | Path: marble → playing games on ground
# 🧪 Epoch 5 | Sample 8080/9741 | Repeat 3/3 | Reward: 0.150 | Path: marble → playing games on ground
# 🧪 Epoch 5 | Sample 8081/9741 | Repeat 1/3 | Reward: 0.150 | Path: going to market → opportunity to buy food products
# 🧪 Epoch 5 | Sample 8081/9741 | Repeat 2/3 | Reward: 0.150 | Path: going to market → opportunity to buy food products
# 🧪 Epoch 5 | Sample 8081/9741 | Repeat 3/3 | Reward: 0.150 | Path: going to market → opportunity to buy food products
# 🧪 Epoch 5 | Sample 8082/9741 | Repeat 1/3 | Reward: 0.150 | Path: go somewhere → have new experience
# 🧪 Epoch 5 | Sample 8082/9741 | Repeat 2/3 | Reward: 0.150 | Path: go somewhere → have new experience
# 🧪 Epoch 5 | Sample 8082/9741 | Repeat 3/3 | Reward: 0.150 | Path: go somewhere → have new experience
# 🧪 Epoch 5 | Sample 8083/9741 | Repeat 1/3 | Reward: 0.150 | Path: finding information → turn on tv
# 🧪 Epoch 5 | Sample 8083/9741 | Repeat 2/3 | Reward: 0.150 | Path: finding information → turn on tv
# 🧪 Epoch 5 | Sample 8083/9741 | Repeat 3/3 | Reward: 0.150 | Path: finding information → turn on tv
# 🧪 Epoch 5 | Sample 8084/9741 | Repeat 1/3 | Reward: 0.150 | Path: delicatessen → buy prepared foods
# 🧪 Epoch 5 | Sample 8084/9741 | Repeat 2/3 | Reward: 0.150 | Path: delicatessen → buy prepared foods
# 🧪 Epoch 5 | Sample 8084/9741 | Repeat 3/3 | Reward: 0.150 | Path: delicatessen → buy prepared foods
# 🧪 Epoch 5 | Sample 8085/9741 | Repeat 1/3 | Reward: 1.150 | Path: attempt → trying
# 🧪 Epoch 5 | Sample 8085/9741 | Repeat 2/3 | Reward: 1.150 | Path: attempt → trying
# 🧪 Epoch 5 | Sample 8085/9741 | Repeat 3/3 | Reward: 1.150 | Path: attempt → trying
# 🧪 Epoch 5 | Sample 8086/9741 | Repeat 1/3 | Reward: 0.150 | Path: standing in line → waiting to get into show
# 🧪 Epoch 5 | Sample 8086/9741 | Repeat 2/3 | Reward: 0.150 | Path: standing in line → waiting to get into show
# 🧪 Epoch 5 | Sample 8086/9741 | Repeat 3/3 | Reward: 0.150 | Path: standing in line → waiting to get into show
# 🧪 Epoch 5 | Sample 8087/9741 | Repeat 1/3 | Reward: 0.150 | Path: water → much more stable than hydrogen peroxide
# 🧪 Epoch 5 | Sample 8087/9741 | Repeat 2/3 | Reward: 0.150 | Path: water → much more stable than hydrogen peroxide
# 🧪 Epoch 5 | Sample 8087/9741 | Repeat 3/3 | Reward: 0.150 | Path: water → much more stable than hydrogen peroxide
# 🧪 Epoch 5 | Sample 8088/9741 | Repeat 1/3 | Reward: 0.150 | Path: soldier → battle another solider
# 🧪 Epoch 5 | Sample 8088/9741 | Repeat 2/3 | Reward: 0.150 | Path: soldier → battle another solider
# 🧪 Epoch 5 | Sample 8088/9741 | Repeat 3/3 | Reward: 0.150 | Path: soldier → battle another solider
# 🧪 Epoch 5 | Sample 8089/9741 | Repeat 1/3 | Reward: 0.150 | Path: jellyfish → sea at coral reefs
# 🧪 Epoch 5 | Sample 8089/9741 | Repeat 2/3 | Reward: 0.150 | Path: jellyfish → sea at coral reefs
# 🧪 Epoch 5 | Sample 8089/9741 | Repeat 3/3 | Reward: 0.150 | Path: jellyfish → sea at coral reefs
# 🧪 Epoch 5 | Sample 8090/9741 | Repeat 1/3 | Reward: 0.150 | Path: dying → remaining people to unhappy
# 🧪 Epoch 5 | Sample 8090/9741 | Repeat 2/3 | Reward: 0.150 | Path: dying → remaining people to unhappy
# 🧪 Epoch 5 | Sample 8090/9741 | Repeat 3/3 | Reward: 0.150 | Path: dying → remaining people to unhappy
# 🧪 Epoch 5 | Sample 8091/9741 | Repeat 1/3 | Reward: 0.150 | Path: pilot → fly to another state
# 🧪 Epoch 5 | Sample 8091/9741 | Repeat 2/3 | Reward: 0.150 | Path: pilot → fly to another state
# 🧪 Epoch 5 | Sample 8091/9741 | Repeat 3/3 | Reward: 0.150 | Path: pilot → fly to another state
# 🧪 Epoch 5 | Sample 8092/9741 | Repeat 1/3 | Reward: 0.150 | Path: competing → going up against better competitor
# 🧪 Epoch 5 | Sample 8092/9741 | Repeat 2/3 | Reward: 0.150 | Path: competing → going up against better competitor
# 🧪 Epoch 5 | Sample 8092/9741 | Repeat 3/3 | Reward: 0.150 | Path: competing → going up against better competitor
# 🧪 Epoch 5 | Sample 8093/9741 | Repeat 1/3 | Reward: 0.150 | Path: marble → playing games on ground
# 🧪 Epoch 5 | Sample 8093/9741 | Repeat 2/3 | Reward: 0.150 | Path: marble → playing games on ground
# 🧪 Epoch 5 | Sample 8093/9741 | Repeat 3/3 | Reward: 0.150 | Path: marble → playing games on ground
# 🧪 Epoch 5 | Sample 8094/9741 | Repeat 1/3 | Reward: 0.150 | Path: have food → getting less hungry
# 🧪 Epoch 5 | Sample 8094/9741 | Repeat 2/3 | Reward: 0.150 | Path: have food → getting less hungry
# 🧪 Epoch 5 | Sample 8094/9741 | Repeat 3/3 | Reward: 0.150 | Path: have food → getting less hungry
# 🧪 Epoch 5 | Sample 8095/9741 | Repeat 1/3 | Reward: 0.150 | Path: setting cup on table → serving coffee or tea
# 🧪 Epoch 5 | Sample 8095/9741 | Repeat 2/3 | Reward: 0.150 | Path: setting cup on table → serving coffee or tea
# 🧪 Epoch 5 | Sample 8095/9741 | Repeat 3/3 | Reward: 0.150 | Path: setting cup on table → serving coffee or tea
# 🧪 Epoch 5 | Sample 8096/9741 | Repeat 1/3 | Reward: 0.150 | Path: material → fabric store
# 🧪 Epoch 5 | Sample 8096/9741 | Repeat 2/3 | Reward: 0.150 | Path: material → fabric store
# 🧪 Epoch 5 | Sample 8096/9741 | Repeat 3/3 | Reward: 0.150 | Path: material → fabric store
# 🧪 Epoch 5 | Sample 8097/9741 | Repeat 1/3 | Reward: 0.150 | Path: french restaurant → eat snails
# 🧪 Epoch 5 | Sample 8097/9741 | Repeat 2/3 | Reward: 0.150 | Path: french restaurant → eat snails
# 🧪 Epoch 5 | Sample 8097/9741 | Repeat 3/3 | Reward: 0.150 | Path: french restaurant → eat snails
# 🧪 Epoch 5 | Sample 8098/9741 | Repeat 1/3 | Reward: 0.150 | Path: getting wet → plants will grow better
# 🧪 Epoch 5 | Sample 8098/9741 | Repeat 2/3 | Reward: 0.150 | Path: getting wet → plants will grow better
# 🧪 Epoch 5 | Sample 8098/9741 | Repeat 3/3 | Reward: 0.150 | Path: getting wet → plants will grow better
# 🧪 Epoch 5 | Sample 8099/9741 | Repeat 1/3 | Reward: 0.150 | Path: fish → laughing at us
# 🧪 Epoch 5 | Sample 8099/9741 | Repeat 2/3 | Reward: 0.150 | Path: fish → laughing at us
# 🧪 Epoch 5 | Sample 8099/9741 | Repeat 3/3 | Reward: 0.150 | Path: fish → laughing at us
# 🧪 Epoch 5 | Sample 8100/9741 | Repeat 1/3 | Reward: 0.150 | Path: person → positive environment
# 🧪 Epoch 5 | Sample 8100/9741 | Repeat 2/3 | Reward: 0.150 | Path: person → positive environment
# 🧪 Epoch 5 | Sample 8100/9741 | Repeat 3/3 | Reward: 0.150 | Path: person → positive environment
# 🧪 Epoch 5 | Sample 8101/9741 | Repeat 1/3 | Reward: 0.150 | Path: water → much more stable than hydrogen peroxide
# 🧪 Epoch 5 | Sample 8101/9741 | Repeat 2/3 | Reward: 0.150 | Path: water → much more stable than hydrogen peroxide
# 🧪 Epoch 5 | Sample 8101/9741 | Repeat 3/3 | Reward: 0.150 | Path: water → much more stable than hydrogen peroxide
# 🧪 Epoch 5 | Sample 8102/9741 | Repeat 1/3 | Reward: 0.150 | Path: cow → supply humans with milk
# 🧪 Epoch 5 | Sample 8102/9741 | Repeat 2/3 | Reward: 0.150 | Path: cow → supply humans with milk
# 🧪 Epoch 5 | Sample 8102/9741 | Repeat 3/3 | Reward: 0.150 | Path: cow → supply humans with milk
# 🧪 Epoch 5 | Sample 8103/9741 | Repeat 1/3 | Reward: 0.150 | Path: learning about science → improving world
# 🧪 Epoch 5 | Sample 8103/9741 | Repeat 2/3 | Reward: 0.150 | Path: learning about science → improving world
# 🧪 Epoch 5 | Sample 8103/9741 | Repeat 3/3 | Reward: 0.150 | Path: learning about science → improving world
# 🧪 Epoch 5 | Sample 8104/9741 | Repeat 1/3 | Reward: 0.150 | Path: winning → important to losers
# 🧪 Epoch 5 | Sample 8104/9741 | Repeat 2/3 | Reward: 0.150 | Path: winning → important to losers
# 🧪 Epoch 5 | Sample 8104/9741 | Repeat 3/3 | Reward: 0.150 | Path: winning → important to losers
# 🧪 Epoch 5 | Sample 8105/9741 | Repeat 1/3 | Reward: 0.150 | Path: food → effect of suppressing hunger
# 🧪 Epoch 5 | Sample 8105/9741 | Repeat 2/3 | Reward: 0.150 | Path: food → effect of suppressing hunger
# 🧪 Epoch 5 | Sample 8105/9741 | Repeat 3/3 | Reward: 0.150 | Path: food → effect of suppressing hunger
# 🧪 Epoch 5 | Sample 8106/9741 | Repeat 1/3 | Reward: 0.150 | Path: elephant → lift logs from ground
# 🧪 Epoch 5 | Sample 8106/9741 | Repeat 2/3 | Reward: 0.150 | Path: elephant → lift logs from ground
# 🧪 Epoch 5 | Sample 8106/9741 | Repeat 3/3 | Reward: 0.150 | Path: elephant → lift logs from ground
# 🧪 Epoch 5 | Sample 8107/9741 | Repeat 1/3 | Reward: 0.150 | Path: luggage → transport clothing while on trip
# 🧪 Epoch 5 | Sample 8107/9741 | Repeat 2/3 | Reward: 0.150 | Path: luggage → transport clothing while on trip
# 🧪 Epoch 5 | Sample 8107/9741 | Repeat 3/3 | Reward: 0.150 | Path: luggage → transport clothing while on trip
# 🧪 Epoch 5 | Sample 8108/9741 | Repeat 1/3 | Reward: 0.150 | Path: finger → smearing on shaving cream
# 🧪 Epoch 5 | Sample 8108/9741 | Repeat 2/3 | Reward: 0.150 | Path: finger → smearing on shaving cream
# 🧪 Epoch 5 | Sample 8108/9741 | Repeat 3/3 | Reward: 0.150 | Path: finger → smearing on shaving cream
# 🧪 Epoch 5 | Sample 8109/9741 | Repeat 1/3 | Reward: 0.150 | Path: road → continue past city limits
# 🧪 Epoch 5 | Sample 8109/9741 | Repeat 2/3 | Reward: 0.150 | Path: road → continue past city limits
# 🧪 Epoch 5 | Sample 8109/9741 | Repeat 3/3 | Reward: 0.150 | Path: road → continue past city limits
# 🧪 Epoch 5 | Sample 8110/9741 | Repeat 1/3 | Reward: 0.150 | Path: ventilation system → getting rid of bad air
# 🧪 Epoch 5 | Sample 8110/9741 | Repeat 2/3 | Reward: 0.150 | Path: ventilation system → getting rid of bad air
# 🧪 Epoch 5 | Sample 8110/9741 | Repeat 3/3 | Reward: 0.150 | Path: ventilation system → getting rid of bad air
# 🧪 Epoch 5 | Sample 8111/9741 | Repeat 1/3 | Reward: 0.150 | Path: grape → microwave will explode
# 🧪 Epoch 5 | Sample 8111/9741 | Repeat 2/3 | Reward: 0.150 | Path: grape → microwave will explode
# 🧪 Epoch 5 | Sample 8111/9741 | Repeat 3/3 | Reward: 0.150 | Path: grape → microwave will explode
# 🧪 Epoch 5 | Sample 8112/9741 | Repeat 1/3 | Reward: 0.150 | Path: release energy → use up nutrients
# 🧪 Epoch 5 | Sample 8112/9741 | Repeat 2/3 | Reward: 0.150 | Path: release energy → use up nutrients
# 🧪 Epoch 5 | Sample 8112/9741 | Repeat 3/3 | Reward: 0.150 | Path: release energy → use up nutrients
# 🧪 Epoch 5 | Sample 8113/9741 | Repeat 1/3 | Reward: 0.250 | Path: hunger → buy fresh fruits and vegetables → have more nutrients fresh
# 🧪 Epoch 5 | Sample 8113/9741 | Repeat 2/3 | Reward: 0.250 | Path: hunger → buy fresh fruits and vegetables → have more nutrients fresh
# 🧪 Epoch 5 | Sample 8113/9741 | Repeat 3/3 | Reward: 0.250 | Path: hunger → buy fresh fruits and vegetables → have more nutrients fresh
# 🧪 Epoch 5 | Sample 8114/9741 | Repeat 1/3 | Reward: 0.150 | Path: friends → make promise
# 🧪 Epoch 5 | Sample 8114/9741 | Repeat 2/3 | Reward: 0.150 | Path: friends → make promise
# 🧪 Epoch 5 | Sample 8114/9741 | Repeat 3/3 | Reward: 0.150 | Path: friends → make promise
# 🧪 Epoch 5 | Sample 8115/9741 | Repeat 1/3 | Reward: 0.150 | Path: cooling off → body temperature would decrease
# 🧪 Epoch 5 | Sample 8115/9741 | Repeat 2/3 | Reward: 0.150 | Path: cooling off → body temperature would decrease
# 🧪 Epoch 5 | Sample 8115/9741 | Repeat 3/3 | Reward: 0.150 | Path: cooling off → body temperature would decrease
# 🧪 Epoch 5 | Sample 8116/9741 | Repeat 1/3 | Reward: 0.150 | Path: audience → boost ego
# 🧪 Epoch 5 | Sample 8116/9741 | Repeat 2/3 | Reward: 0.150 | Path: audience → boost ego
# 🧪 Epoch 5 | Sample 8116/9741 | Repeat 3/3 | Reward: 0.150 | Path: audience → boost ego
# 🧪 Epoch 5 | Sample 8117/9741 | Repeat 1/3 | Reward: 0.150 | Path: human → learn whether milk causes prostate cancer
# 🧪 Epoch 5 | Sample 8117/9741 | Repeat 2/3 | Reward: 0.150 | Path: human → learn whether milk causes prostate cancer
# 🧪 Epoch 5 | Sample 8117/9741 | Repeat 3/3 | Reward: 0.150 | Path: human → learn whether milk causes prostate cancer
# 🧪 Epoch 5 | Sample 8118/9741 | Repeat 1/3 | Reward: 0.150 | Path: lawn → playing bowls on
# 🧪 Epoch 5 | Sample 8118/9741 | Repeat 2/3 | Reward: 0.150 | Path: lawn → playing bowls on
# 🧪 Epoch 5 | Sample 8118/9741 | Repeat 3/3 | Reward: 0.150 | Path: lawn → playing bowls on
# 🧪 Epoch 5 | Sample 8119/9741 | Repeat 1/3 | Reward: 0.150 | Path: refill → get more soda
# 🧪 Epoch 5 | Sample 8119/9741 | Repeat 2/3 | Reward: 0.150 | Path: refill → get more soda
# 🧪 Epoch 5 | Sample 8119/9741 | Repeat 3/3 | Reward: 0.150 | Path: refill → get more soda
# 🧪 Epoch 5 | Sample 8120/9741 | Repeat 1/3 | Reward: 0.150 | Path: marmoset → cage at zoo
# 🧪 Epoch 5 | Sample 8120/9741 | Repeat 2/3 | Reward: 0.150 | Path: marmoset → cage at zoo
# 🧪 Epoch 5 | Sample 8120/9741 | Repeat 3/3 | Reward: 0.150 | Path: marmoset → cage at zoo
# 🧪 Epoch 5 | Sample 8121/9741 | Repeat 1/3 | Reward: 0.150 | Path: children → better at video games than adults
# 🧪 Epoch 5 | Sample 8121/9741 | Repeat 2/3 | Reward: 0.150 | Path: children → better at video games than adults
# 🧪 Epoch 5 | Sample 8121/9741 | Repeat 3/3 | Reward: 0.150 | Path: children → better at video games than adults
# 🧪 Epoch 5 | Sample 8122/9741 | Repeat 1/3 | Reward: 0.150 | Path: steel cable → many different purposes
# 🧪 Epoch 5 | Sample 8122/9741 | Repeat 2/3 | Reward: 0.150 | Path: steel cable → support great weight
# 🧪 Epoch 5 | Sample 8122/9741 | Repeat 3/3 | Reward: 0.150 | Path: steel cable → support great weight
# 🧪 Epoch 5 | Sample 8123/9741 | Repeat 1/3 | Reward: 0.150 | Path: mat → keeping floor clean
# 🧪 Epoch 5 | Sample 8123/9741 | Repeat 2/3 | Reward: 0.150 | Path: mat → keeping floor clean
# 🧪 Epoch 5 | Sample 8123/9741 | Repeat 3/3 | Reward: 0.150 | Path: mat → keeping floor clean
# 🧪 Epoch 5 | Sample 8124/9741 | Repeat 1/3 | Reward: 0.150 | Path: candle → creating mood
# 🧪 Epoch 5 | Sample 8124/9741 | Repeat 2/3 | Reward: 0.150 | Path: candle → creating mood
# 🧪 Epoch 5 | Sample 8124/9741 | Repeat 3/3 | Reward: 0.150 | Path: candle → creating mood
# 🧪 Epoch 5 | Sample 8125/9741 | Repeat 1/3 | Reward: 0.150 | Path: washing hands → health reasons
# 🧪 Epoch 5 | Sample 8125/9741 | Repeat 2/3 | Reward: 0.150 | Path: washing hands → health reasons
# 🧪 Epoch 5 | Sample 8125/9741 | Repeat 3/3 | Reward: 0.150 | Path: washing hands → health reasons
# 🧪 Epoch 5 | Sample 8126/9741 | Repeat 1/3 | Reward: 0.150 | Path: launch platform → send rocket off into space
# 🧪 Epoch 5 | Sample 8126/9741 | Repeat 2/3 | Reward: 0.150 | Path: launch platform → send rocket off into space
# 🧪 Epoch 5 | Sample 8126/9741 | Repeat 3/3 | Reward: 0.150 | Path: launch platform → send rocket off into space
# 🧪 Epoch 5 | Sample 8127/9741 | Repeat 1/3 | Reward: 0.606 | Path: drunk → raise hell → raise hell → raise hell → raise hell → raise hell → raise hell → raise hell → raise hell → raise hell → raise hell
# 🧪 Epoch 5 | Sample 8127/9741 | Repeat 2/3 | Reward: 0.606 | Path: drunk → raise hell → raise hell → raise hell → raise hell → raise hell → raise hell → raise hell → raise hell → raise hell → raise hell
# 🧪 Epoch 5 | Sample 8127/9741 | Repeat 3/3 | Reward: 0.606 | Path: drunk → raise hell → raise hell → raise hell → raise hell → raise hell → raise hell → raise hell → raise hell → raise hell → raise hell
# 🧪 Epoch 5 | Sample 8128/9741 | Repeat 1/3 | Reward: 0.150 | Path: restaurant → satisfy hunger
# 🧪 Epoch 5 | Sample 8128/9741 | Repeat 2/3 | Reward: 0.150 | Path: restaurant → satisfy hunger
# 🧪 Epoch 5 | Sample 8128/9741 | Repeat 3/3 | Reward: 0.150 | Path: restaurant → satisfy hunger
# 🧪 Epoch 5 | Sample 8129/9741 | Repeat 1/3 | Reward: 0.150 | Path: advertisement → increasing company's profits
# 🧪 Epoch 5 | Sample 8129/9741 | Repeat 2/3 | Reward: 0.150 | Path: advertisement → increasing company's profits
# 🧪 Epoch 5 | Sample 8129/9741 | Repeat 3/3 | Reward: 0.150 | Path: advertisement → increasing company's profits
# 🧪 Epoch 5 | Sample 8130/9741 | Repeat 1/3 | Reward: 0.150 | Path: water → much more stable than hydrogen peroxide
# 🧪 Epoch 5 | Sample 8130/9741 | Repeat 2/3 | Reward: 0.150 | Path: water → much more stable than hydrogen peroxide
# 🧪 Epoch 5 | Sample 8130/9741 | Repeat 3/3 | Reward: 0.150 | Path: water → much more stable than hydrogen peroxide
# 🧪 Epoch 5 | Sample 8131/9741 | Repeat 1/3 | Reward: 0.250 | Path: neighbour → remote → remotely control tv
# 🧪 Epoch 5 | Sample 8131/9741 | Repeat 2/3 | Reward: 0.250 | Path: neighbour → remote → remotely control tv
# 🧪 Epoch 5 | Sample 8131/9741 | Repeat 3/3 | Reward: 0.250 | Path: neighbour → remote → remotely control tv
# 🧪 Epoch 5 | Sample 8132/9741 | Repeat 1/3 | Reward: 0.150 | Path: noise → bug people sleeping
# 🧪 Epoch 5 | Sample 8132/9741 | Repeat 2/3 | Reward: 0.150 | Path: noise → bug people sleeping
# 🧪 Epoch 5 | Sample 8132/9741 | Repeat 3/3 | Reward: 0.150 | Path: noise → bug people sleeping
# 🧪 Epoch 5 | Sample 8133/9741 | Repeat 1/3 | Reward: 0.150 | Path: copulate → more children
# 🧪 Epoch 5 | Sample 8133/9741 | Repeat 2/3 | Reward: 0.150 | Path: copulate → want to have children
# 🧪 Epoch 5 | Sample 8133/9741 | Repeat 3/3 | Reward: 0.150 | Path: copulate → want to have children
# 🧪 Epoch 5 | Sample 8134/9741 | Repeat 1/3 | Reward: 0.150 | Path: basement → storage of produce
# 🧪 Epoch 5 | Sample 8134/9741 | Repeat 2/3 | Reward: 0.150 | Path: basement → storage of produce
# 🧪 Epoch 5 | Sample 8134/9741 | Repeat 3/3 | Reward: 0.150 | Path: basement → storage of produce
# 🧪 Epoch 5 | Sample 8135/9741 | Repeat 1/3 | Reward: 0.150 | Path: bass drum → venting emotion
# 🧪 Epoch 5 | Sample 8135/9741 | Repeat 2/3 | Reward: 0.150 | Path: bass drum → venting emotion
# 🧪 Epoch 5 | Sample 8135/9741 | Repeat 3/3 | Reward: 0.150 | Path: bass drum → venting emotion
# 🧪 Epoch 5 | Sample 8136/9741 | Repeat 1/3 | Reward: 0.150 | Path: seeing old things → being filled with nostalgia
# 🧪 Epoch 5 | Sample 8136/9741 | Repeat 2/3 | Reward: 0.150 | Path: seeing old things → being filled with nostalgia
# 🧪 Epoch 5 | Sample 8136/9741 | Repeat 3/3 | Reward: 0.150 | Path: seeing old things → being filled with nostalgia
# 🧪 Epoch 5 | Sample 8137/9741 | Repeat 1/3 | Reward: 0.150 | Path: dogs → sleep on bed
# 🧪 Epoch 5 | Sample 8137/9741 | Repeat 2/3 | Reward: 0.150 | Path: dogs → sleep on bed
# 🧪 Epoch 5 | Sample 8137/9741 | Repeat 3/3 | Reward: 0.150 | Path: dogs → sleep on bed
# 🧪 Epoch 5 | Sample 8138/9741 | Repeat 1/3 | Reward: 0.150 | Path: climbing → fear of heights
# 🧪 Epoch 5 | Sample 8138/9741 | Repeat 2/3 | Reward: 0.150 | Path: climbing → fear of heights
# 🧪 Epoch 5 | Sample 8138/9741 | Repeat 3/3 | Reward: 0.150 | Path: climbing → fear of heights
# 🧪 Epoch 5 | Sample 8139/9741 | Repeat 1/3 | Reward: 0.150 | Path: passageway → sneak around in castle
# 🧪 Epoch 5 | Sample 8139/9741 | Repeat 2/3 | Reward: 0.150 | Path: passageway → sneak around in castle
# 🧪 Epoch 5 | Sample 8139/9741 | Repeat 3/3 | Reward: 0.150 | Path: passageway → sneak around in castle
# 🧪 Epoch 5 | Sample 8140/9741 | Repeat 1/3 | Reward: 0.150 | Path: fart → people would offended
# 🧪 Epoch 5 | Sample 8140/9741 | Repeat 2/3 | Reward: 0.150 | Path: fart → people would offended
# 🧪 Epoch 5 | Sample 8140/9741 | Repeat 3/3 | Reward: 0.150 | Path: fart → people would offended
# 🧪 Epoch 5 | Sample 8141/9741 | Repeat 1/3 | Reward: 0.385 | Path: twist → card games → card game → card → fall on floor
# 🧪 Epoch 5 | Sample 8141/9741 | Repeat 2/3 | Reward: 0.385 | Path: twist → card games → card game → card → fall on floor
# 🧪 Epoch 5 | Sample 8141/9741 | Repeat 3/3 | Reward: 0.385 | Path: twist → card games → card game → card → fall on floor
# 🧪 Epoch 5 | Sample 8142/9741 | Repeat 1/3 | Reward: 0.150 | Path: ficus → store sells plants
# 🧪 Epoch 5 | Sample 8142/9741 | Repeat 2/3 | Reward: 0.150 | Path: ficus → store sells plants
# 🧪 Epoch 5 | Sample 8142/9741 | Repeat 3/3 | Reward: 0.150 | Path: ficus → store sells plants
# 🧪 Epoch 5 | Sample 8143/9741 | Repeat 1/3 | Reward: 0.150 | Path: meet interesting people → save world
# 🧪 Epoch 5 | Sample 8143/9741 | Repeat 2/3 | Reward: 0.150 | Path: meet interesting people → save world
# 🧪 Epoch 5 | Sample 8143/9741 | Repeat 3/3 | Reward: 0.150 | Path: meet interesting people → save world
# 🧪 Epoch 5 | Sample 8144/9741 | Repeat 1/3 | Reward: 0.150 | Path: hill → getting higher
# 🧪 Epoch 5 | Sample 8144/9741 | Repeat 2/3 | Reward: 0.150 | Path: hill → getting higher
# 🧪 Epoch 5 | Sample 8144/9741 | Repeat 3/3 | Reward: 0.150 | Path: hill → getting higher
# 🧪 Epoch 5 | Sample 8145/9741 | Repeat 1/3 | Reward: 0.435 | Path: home → sanctuary → place of refuge → retreat → treat → trick or
# 🧪 Epoch 5 | Sample 8145/9741 | Repeat 2/3 | Reward: 0.435 | Path: home → sanctuary → place of refuge → retreat → treat → trick or
# 🧪 Epoch 5 | Sample 8145/9741 | Repeat 3/3 | Reward: 0.435 | Path: home → sanctuary → place of refuge → retreat → treat → trick or
# 🧪 Epoch 5 | Sample 8146/9741 | Repeat 1/3 | Reward: 0.150 | Path: people → fear people living in other countries
# 🧪 Epoch 5 | Sample 8146/9741 | Repeat 2/3 | Reward: 0.150 | Path: people → fear people living in other countries
# 🧪 Epoch 5 | Sample 8146/9741 | Repeat 3/3 | Reward: 0.150 | Path: people → fear people living in other countries
# 🧪 Epoch 5 | Sample 8147/9741 | Repeat 1/3 | Reward: 0.150 | Path: spend money → cash supply decreases
# 🧪 Epoch 5 | Sample 8147/9741 | Repeat 2/3 | Reward: 0.150 | Path: spend money → cash supply decreases
# 🧪 Epoch 5 | Sample 8147/9741 | Repeat 3/3 | Reward: 0.150 | Path: spend money → cash supply decreases
# 🧪 Epoch 5 | Sample 8148/9741 | Repeat 1/3 | Reward: 0.250 | Path: riding horse → fear → force people to hide
# 🧪 Epoch 5 | Sample 8148/9741 | Repeat 2/3 | Reward: 0.250 | Path: riding horse → fear → force people to hide
# 🧪 Epoch 5 | Sample 8148/9741 | Repeat 3/3 | Reward: 0.250 | Path: riding horse → fear → force people to hide
# 🧪 Epoch 5 | Sample 8149/9741 | Repeat 1/3 | Reward: 0.150 | Path: person → positive environment
# 🧪 Epoch 5 | Sample 8149/9741 | Repeat 2/3 | Reward: 0.150 | Path: person → positive environment
# 🧪 Epoch 5 | Sample 8149/9741 | Repeat 3/3 | Reward: 0.150 | Path: person → positive environment
# 🧪 Epoch 5 | Sample 8150/9741 | Repeat 1/3 | Reward: 0.150 | Path: dogs → sleep on bed
# 🧪 Epoch 5 | Sample 8150/9741 | Repeat 2/3 | Reward: 0.150 | Path: dogs → sleep on bed
# 🧪 Epoch 5 | Sample 8150/9741 | Repeat 3/3 | Reward: 0.150 | Path: dogs → sleep on bed
# 🧪 Epoch 5 | Sample 8151/9741 | Repeat 1/3 | Reward: 0.325 | Path: excitement → excite → relax → recover energy or reduce stress
# 🧪 Epoch 5 | Sample 8151/9741 | Repeat 2/3 | Reward: 0.325 | Path: excitement → excite → relax → recover energy or reduce stress
# 🧪 Epoch 5 | Sample 8151/9741 | Repeat 3/3 | Reward: 0.325 | Path: excitement → excite → relax → recover energy or reduce stress
# 🧪 Epoch 5 | Sample 8152/9741 | Repeat 1/3 | Reward: 0.150 | Path: humans → have control over environment
# 🧪 Epoch 5 | Sample 8152/9741 | Repeat 2/3 | Reward: 0.150 | Path: humans → have control over environment
# 🧪 Epoch 5 | Sample 8152/9741 | Repeat 3/3 | Reward: 0.150 | Path: humans → have control over environment
# 🧪 Epoch 5 | Sample 8153/9741 | Repeat 1/3 | Reward: 0.150 | Path: animal → sense fear in human
# 🧪 Epoch 5 | Sample 8153/9741 | Repeat 2/3 | Reward: 0.150 | Path: animal → sense fear in human
# 🧪 Epoch 5 | Sample 8153/9741 | Repeat 3/3 | Reward: 0.150 | Path: animal → sense fear in human
# 🧪 Epoch 5 | Sample 8154/9741 | Repeat 1/3 | Reward: 0.150 | Path: communicating → teaching new things
# 🧪 Epoch 5 | Sample 8154/9741 | Repeat 2/3 | Reward: 0.150 | Path: communicating → teaching new things
# 🧪 Epoch 5 | Sample 8154/9741 | Repeat 3/3 | Reward: 0.150 | Path: communicating → teaching new things
# 🧪 Epoch 5 | Sample 8155/9741 | Repeat 1/3 | Reward: 0.606 | Path: blow → suction → evacuate → move → sit still → tolerate → allow → forbid → command → serve → effect
# 🧪 Epoch 5 | Sample 8155/9741 | Repeat 2/3 | Reward: 0.606 | Path: blow → suction → evacuate → move → sit still → tolerate → allow → forbid → command → serve → effect
# 🧪 Epoch 5 | Sample 8155/9741 | Repeat 3/3 | Reward: 0.606 | Path: blow → suction → evacuate → move → sit still → tolerate → allow → forbid → command → serve → effect
# 🧪 Epoch 5 | Sample 8156/9741 | Repeat 1/3 | Reward: 0.150 | Path: island → host survivor game
# 🧪 Epoch 5 | Sample 8156/9741 | Repeat 2/3 | Reward: 0.150 | Path: island → host survivor game
# 🧪 Epoch 5 | Sample 8156/9741 | Repeat 3/3 | Reward: 0.150 | Path: island → host survivor game
# 🧪 Epoch 5 | Sample 8157/9741 | Repeat 1/3 | Reward: 0.150 | Path: fencing → keeping animals out of garden
# 🧪 Epoch 5 | Sample 8157/9741 | Repeat 2/3 | Reward: 0.150 | Path: fencing → keeping animals out of garden
# 🧪 Epoch 5 | Sample 8157/9741 | Repeat 3/3 | Reward: 0.150 | Path: fencing → keeping animals out of garden
# 🧪 Epoch 5 | Sample 8158/9741 | Repeat 1/3 | Reward: 0.150 | Path: listening to music → audience to affected
# 🧪 Epoch 5 | Sample 8158/9741 | Repeat 2/3 | Reward: 0.150 | Path: listening to music → effect of making one relax
# 🧪 Epoch 5 | Sample 8158/9741 | Repeat 3/3 | Reward: 0.150 | Path: listening to music → audience to affected
# 🧪 Epoch 5 | Sample 8159/9741 | Repeat 1/3 | Reward: 0.150 | Path: leader → present people new hope
# 🧪 Epoch 5 | Sample 8159/9741 | Repeat 2/3 | Reward: 0.150 | Path: leader → present people new hope
# 🧪 Epoch 5 | Sample 8159/9741 | Repeat 3/3 | Reward: 0.150 | Path: leader → present people new hope
# 🧪 Epoch 5 | Sample 8160/9741 | Repeat 1/3 | Reward: 0.150 | Path: people → fear people living in other countries
# 🧪 Epoch 5 | Sample 8160/9741 | Repeat 2/3 | Reward: 0.150 | Path: people → fear people living in other countries
# 🧪 Epoch 5 | Sample 8160/9741 | Repeat 3/3 | Reward: 0.150 | Path: people → fear people living in other countries
# 🧪 Epoch 5 | Sample 8161/9741 | Repeat 1/3 | Reward: 0.150 | Path: rule → restrict behavior
# 🧪 Epoch 5 | Sample 8161/9741 | Repeat 2/3 | Reward: 0.150 | Path: rule → restrict behavior
# 🧪 Epoch 5 | Sample 8161/9741 | Repeat 3/3 | Reward: 0.150 | Path: rule → restrict behavior
# 🧪 Epoch 5 | Sample 8162/9741 | Repeat 1/3 | Reward: 0.150 | Path: injury → disable enemy
# 🧪 Epoch 5 | Sample 8162/9741 | Repeat 2/3 | Reward: 0.150 | Path: injury → disable enemy
# 🧪 Epoch 5 | Sample 8162/9741 | Repeat 3/3 | Reward: 0.150 | Path: injury → disable enemy
# 🧪 Epoch 5 | Sample 8163/9741 | Repeat 1/3 | Reward: 0.150 | Path: illness → avoid work
# 🧪 Epoch 5 | Sample 8163/9741 | Repeat 2/3 | Reward: 0.150 | Path: illness → avoid work
# 🧪 Epoch 5 | Sample 8163/9741 | Repeat 3/3 | Reward: 0.150 | Path: illness → avoid work
# 🧪 Epoch 5 | Sample 8164/9741 | Repeat 1/3 | Reward: 0.150 | Path: committing suicide → keeping counselling industry viable
# 🧪 Epoch 5 | Sample 8164/9741 | Repeat 2/3 | Reward: 0.150 | Path: committing suicide → keeping counselling industry viable
# 🧪 Epoch 5 | Sample 8164/9741 | Repeat 3/3 | Reward: 0.150 | Path: committing suicide → keeping counselling industry viable
# 🧪 Epoch 5 | Sample 8165/9741 | Repeat 1/3 | Reward: 0.150 | Path: pilot → fly to another state
# 🧪 Epoch 5 | Sample 8165/9741 | Repeat 2/3 | Reward: 0.150 | Path: pilot → fly to another state
# 🧪 Epoch 5 | Sample 8165/9741 | Repeat 3/3 | Reward: 0.150 | Path: pilot → fly to another state
# 🧪 Epoch 5 | Sample 8166/9741 | Repeat 1/3 | Reward: 0.150 | Path: swimming pool → reducing lawn mowing area
# 🧪 Epoch 5 | Sample 8166/9741 | Repeat 2/3 | Reward: 0.150 | Path: swimming pool → reducing lawn mowing area
# 🧪 Epoch 5 | Sample 8166/9741 | Repeat 3/3 | Reward: 0.150 | Path: swimming pool → reducing lawn mowing area
# 🧪 Epoch 5 | Sample 8167/9741 | Repeat 1/3 | Reward: 0.150 | Path: air conditioner → reduce room temperature
# 🧪 Epoch 5 | Sample 8167/9741 | Repeat 2/3 | Reward: 0.150 | Path: air conditioner → reduce room temperature
# 🧪 Epoch 5 | Sample 8167/9741 | Repeat 3/3 | Reward: 0.150 | Path: air conditioner → reduce room temperature
# 🧪 Epoch 5 | Sample 8168/9741 | Repeat 1/3 | Reward: 0.606 | Path: sunshine → harmful → beneficial → benefit → disadvantage → advantage → disadvantage → advantage → disadvantage → advantage → disadvantage
# 🧪 Epoch 5 | Sample 8168/9741 | Repeat 2/3 | Reward: 0.606 | Path: sunshine → harmful → beneficial → benefit → disadvantage → advantage → disadvantage → advantage → disadvantage → advantage → disadvantage
# 🧪 Epoch 5 | Sample 8168/9741 | Repeat 3/3 | Reward: 0.606 | Path: sunshine → harmful → beneficial → benefit → disadvantage → advantage → disadvantage → advantage → disadvantage → advantage → disadvantage
# 🧪 Epoch 5 | Sample 8169/9741 | Repeat 1/3 | Reward: 0.150 | Path: door → entering or exiting room
# 🧪 Epoch 5 | Sample 8169/9741 | Repeat 2/3 | Reward: 0.150 | Path: door → entering or exiting room
# 🧪 Epoch 5 | Sample 8169/9741 | Repeat 3/3 | Reward: 0.150 | Path: door → entering or exiting room
# 🧪 Epoch 5 | Sample 8170/9741 | Repeat 1/3 | Reward: 0.150 | Path: starting fire → gather up kindling
# 🧪 Epoch 5 | Sample 8170/9741 | Repeat 2/3 | Reward: 0.150 | Path: starting fire → gather up kindling
# 🧪 Epoch 5 | Sample 8170/9741 | Repeat 3/3 | Reward: 0.150 | Path: starting fire → gather up kindling
# 🧪 Epoch 5 | Sample 8171/9741 | Repeat 1/3 | Reward: 0.150 | Path: appointment book → keep calendar
# 🧪 Epoch 5 | Sample 8171/9741 | Repeat 2/3 | Reward: 0.150 | Path: appointment book → keep calendar
# 🧪 Epoch 5 | Sample 8171/9741 | Repeat 3/3 | Reward: 0.150 | Path: appointment book → keep calendar
# 🧪 Epoch 5 | Sample 8172/9741 | Repeat 1/3 | Reward: 0.549 | Path: side chair → sit in → sit → getting up → get up → sit down → change posture → change → couch seats
# 🧪 Epoch 5 | Sample 8172/9741 | Repeat 2/3 | Reward: 0.549 | Path: side chair → sit in → sit → getting up → get up → sit down → change posture → change → couch seats
# 🧪 Epoch 5 | Sample 8172/9741 | Repeat 3/3 | Reward: 0.549 | Path: side chair → sit in → sit → getting up → get up → sit down → change posture → change → couch seats
# 🧪 Epoch 5 | Sample 8173/9741 | Repeat 1/3 | Reward: 0.150 | Path: thunder → surprise people
# 🧪 Epoch 5 | Sample 8173/9741 | Repeat 2/3 | Reward: 0.150 | Path: thunder → surprise people
# 🧪 Epoch 5 | Sample 8173/9741 | Repeat 3/3 | Reward: 0.150 | Path: thunder → surprise people
# 🧪 Epoch 5 | Sample 8174/9741 | Repeat 1/3 | Reward: 0.150 | Path: stamps → adhesive backing
# 🧪 Epoch 5 | Sample 8174/9741 | Repeat 2/3 | Reward: 0.150 | Path: stamps → adhesive backing
# 🧪 Epoch 5 | Sample 8174/9741 | Repeat 3/3 | Reward: 0.150 | Path: stamps → adhesive backing
# 🧪 Epoch 5 | Sample 8175/9741 | Repeat 1/3 | Reward: 0.325 | Path: going to bed → bad dreams → wake up → turn off alarm clock
# 🧪 Epoch 5 | Sample 8175/9741 | Repeat 2/3 | Reward: 0.325 | Path: going to bed → bad dreams → wake up → turn off alarm clock
# 🧪 Epoch 5 | Sample 8175/9741 | Repeat 3/3 | Reward: 0.325 | Path: going to bed → bad dreams → wake up → turn off alarm clock
# 🧪 Epoch 5 | Sample 8176/9741 | Repeat 1/3 | Reward: 0.150 | Path: shirts → mobile billboards for company logos
# 🧪 Epoch 5 | Sample 8176/9741 | Repeat 2/3 | Reward: 0.150 | Path: shirts → mobile billboards for company logos
# 🧪 Epoch 5 | Sample 8176/9741 | Repeat 3/3 | Reward: 0.150 | Path: shirts → mobile billboards for company logos
# 🧪 Epoch 5 | Sample 8177/9741 | Repeat 1/3 | Reward: 0.150 | Path: surface → put things on
# 🧪 Epoch 5 | Sample 8177/9741 | Repeat 2/3 | Reward: 0.150 | Path: surface → putting things on
# 🧪 Epoch 5 | Sample 8177/9741 | Repeat 3/3 | Reward: 0.150 | Path: surface → putting things on
# 🧪 Epoch 5 | Sample 8178/9741 | Repeat 1/3 | Reward: 0.549 | Path: nonessential → mandatory → advisory → advise → counsel → counseling → false → true → opposite of false
# 🧪 Epoch 5 | Sample 8178/9741 | Repeat 2/3 | Reward: 0.549 | Path: nonessential → mandatory → advisory → advise → counsel → counseling → false → true → opposite of false
# 🧪 Epoch 5 | Sample 8178/9741 | Repeat 3/3 | Reward: 0.606 | Path: nonessential → mandatory → advisory → advise → counsel → advise → counsel → advise → counsel → counseling → false
# 🧪 Epoch 5 | Sample 8179/9741 | Repeat 1/3 | Reward: 1.150 | Path: faith → despair
# 🧪 Epoch 5 | Sample 8179/9741 | Repeat 2/3 | Reward: 1.150 | Path: faith → despair
# 🧪 Epoch 5 | Sample 8179/9741 | Repeat 3/3 | Reward: 1.150 | Path: faith → despair
# 🧪 Epoch 5 | Sample 8180/9741 | Repeat 1/3 | Reward: 0.150 | Path: fighting inflation → protecting consumers
# 🧪 Epoch 5 | Sample 8180/9741 | Repeat 2/3 | Reward: 0.150 | Path: fighting inflation → protecting consumers
# 🧪 Epoch 5 | Sample 8180/9741 | Repeat 3/3 | Reward: 0.150 | Path: fighting inflation → protecting consumers
# 🧪 Epoch 5 | Sample 8181/9741 | Repeat 1/3 | Reward: 0.150 | Path: horse → making fermented mare's milk
# 🧪 Epoch 5 | Sample 8181/9741 | Repeat 2/3 | Reward: 0.150 | Path: horse → making fermented mare's milk
# 🧪 Epoch 5 | Sample 8181/9741 | Repeat 3/3 | Reward: 0.150 | Path: horse → making fermented mare's milk
# 🧪 Epoch 5 | Sample 8182/9741 | Repeat 1/3 | Reward: 0.606 | Path: sunshine → harmful → beneficial → benefit → disadvantage → advantage → disadvantage → advantage → disadvantage → advantage → disadvantage
# 🧪 Epoch 5 | Sample 8182/9741 | Repeat 2/3 | Reward: 0.606 | Path: sunshine → harmful → beneficial → benefit → disadvantage → advantage → disadvantage → advantage → disadvantage → advantage → disadvantage
# 🧪 Epoch 5 | Sample 8182/9741 | Repeat 3/3 | Reward: 0.606 | Path: sunshine → harmful → beneficial → benefit → disadvantage → advantage → disadvantage → advantage → disadvantage → advantage → disadvantage
# 🧪 Epoch 5 | Sample 8183/9741 | Repeat 1/3 | Reward: 0.150 | Path: eating breakfast → not liking eggs anymore
# 🧪 Epoch 5 | Sample 8183/9741 | Repeat 2/3 | Reward: 0.150 | Path: eating breakfast → not liking eggs anymore
# 🧪 Epoch 5 | Sample 8183/9741 | Repeat 3/3 | Reward: 0.150 | Path: eating breakfast → not liking eggs anymore
# 🧪 Epoch 5 | Sample 8184/9741 | Repeat 1/3 | Reward: 0.150 | Path: cry → be happy
# 🧪 Epoch 5 | Sample 8184/9741 | Repeat 2/3 | Reward: 0.150 | Path: cry → be happy
# 🧪 Epoch 5 | Sample 8184/9741 | Repeat 3/3 | Reward: 0.150 | Path: cry → be happy
# 🧪 Epoch 5 | Sample 8185/9741 | Repeat 1/3 | Reward: 0.150 | Path: person → positive environment
# 🧪 Epoch 5 | Sample 8185/9741 | Repeat 2/3 | Reward: 0.150 | Path: person → positive environment
# 🧪 Epoch 5 | Sample 8185/9741 | Repeat 3/3 | Reward: 0.150 | Path: person → positive environment
# 🧪 Epoch 5 | Sample 8186/9741 | Repeat 1/3 | Reward: 0.325 | Path: going to play → happiness → fiddle → put fiddle away
# 🧪 Epoch 5 | Sample 8186/9741 | Repeat 2/3 | Reward: 0.325 | Path: going to play → happiness → fiddle → put fiddle away
# 🧪 Epoch 5 | Sample 8186/9741 | Repeat 3/3 | Reward: 0.325 | Path: going to play → happiness → fiddle → put fiddle away
# 🧪 Epoch 5 | Sample 8187/9741 | Repeat 1/3 | Reward: 0.150 | Path: potato → ground before it's harvested
# 🧪 Epoch 5 | Sample 8187/9741 | Repeat 2/3 | Reward: 0.150 | Path: potato → ground before it's harvested
# 🧪 Epoch 5 | Sample 8187/9741 | Repeat 3/3 | Reward: 0.150 | Path: potato → ground before it's harvested
# 🧪 Epoch 5 | Sample 8188/9741 | Repeat 1/3 | Reward: 0.150 | Path: plain → visibility to horizon
# 🧪 Epoch 5 | Sample 8188/9741 | Repeat 2/3 | Reward: 0.150 | Path: plain → visibility to horizon
# 🧪 Epoch 5 | Sample 8188/9741 | Repeat 3/3 | Reward: 0.150 | Path: plain → visibility to horizon
# 🧪 Epoch 5 | Sample 8189/9741 | Repeat 1/3 | Reward: 0.150 | Path: live life → end up happy
# 🧪 Epoch 5 | Sample 8189/9741 | Repeat 2/3 | Reward: 0.150 | Path: live life → end up happy
# 🧪 Epoch 5 | Sample 8189/9741 | Repeat 3/3 | Reward: 0.150 | Path: live life → end up happy
# 🧪 Epoch 5 | Sample 8190/9741 | Repeat 1/3 | Reward: 0.150 | Path: wait tables → deal with angry customers
# 🧪 Epoch 5 | Sample 8190/9741 | Repeat 2/3 | Reward: 0.150 | Path: wait tables → deal with angry customers
# 🧪 Epoch 5 | Sample 8190/9741 | Repeat 3/3 | Reward: 0.150 | Path: wait tables → deal with angry customers
# 🧪 Epoch 5 | Sample 8191/9741 | Repeat 1/3 | Reward: 0.150 | Path: horse → making fermented mare's milk
# 🧪 Epoch 5 | Sample 8191/9741 | Repeat 2/3 | Reward: 0.150 | Path: horse → making fermented mare's milk
# 🧪 Epoch 5 | Sample 8191/9741 | Repeat 3/3 | Reward: 0.150 | Path: horse → making fermented mare's milk
# 🧪 Epoch 5 | Sample 8192/9741 | Repeat 1/3 | Reward: 0.150 | Path: play cards → place card face down
# 🧪 Epoch 5 | Sample 8192/9741 | Repeat 2/3 | Reward: 0.150 | Path: play cards → place card face down
# 🧪 Epoch 5 | Sample 8192/9741 | Repeat 3/3 | Reward: 0.150 | Path: play cards → place card face down
# 🧪 Epoch 5 | Sample 8193/9741 | Repeat 1/3 | Reward: 0.150 | Path: person → positive environment
# 🧪 Epoch 5 | Sample 8193/9741 | Repeat 2/3 | Reward: 0.150 | Path: person → positive environment
# 🧪 Epoch 5 | Sample 8193/9741 | Repeat 3/3 | Reward: 0.150 | Path: person → positive environment
# 🧪 Epoch 5 | Sample 8194/9741 | Repeat 1/3 | Reward: 0.150 | Path: fox → kill chickens
# 🧪 Epoch 5 | Sample 8194/9741 | Repeat 2/3 | Reward: 0.150 | Path: fox → kill chickens
# 🧪 Epoch 5 | Sample 8194/9741 | Repeat 3/3 | Reward: 0.150 | Path: fox → kill chickens
# 🧪 Epoch 5 | Sample 8195/9741 | Repeat 1/3 | Reward: 1.150 | Path: massive → dwarf
# 🧪 Epoch 5 | Sample 8195/9741 | Repeat 2/3 | Reward: 1.150 | Path: massive → dwarf
# 🧪 Epoch 5 | Sample 8195/9741 | Repeat 3/3 | Reward: 1.150 | Path: massive → dwarf
# 🧪 Epoch 5 | Sample 8196/9741 | Repeat 1/3 | Reward: 0.250 | Path: mouthpiece → respirator → respirate
# 🧪 Epoch 5 | Sample 8196/9741 | Repeat 2/3 | Reward: 0.250 | Path: mouthpiece → respirator → respirate
# 🧪 Epoch 5 | Sample 8196/9741 | Repeat 3/3 | Reward: 0.250 | Path: mouthpiece → respirator → respirate
# 🧪 Epoch 5 | Sample 8197/9741 | Repeat 1/3 | Reward: 0.150 | Path: shed → store materials out of weather
# 🧪 Epoch 5 | Sample 8197/9741 | Repeat 2/3 | Reward: 0.150 | Path: shed → store materials out of weather
# 🧪 Epoch 5 | Sample 8197/9741 | Repeat 3/3 | Reward: 0.150 | Path: shed → store materials out of weather
# 🧪 Epoch 5 | Sample 8198/9741 | Repeat 1/3 | Reward: 0.150 | Path: people → fear people living in other countries
# 🧪 Epoch 5 | Sample 8198/9741 | Repeat 2/3 | Reward: 0.150 | Path: people → fear people living in other countries
# 🧪 Epoch 5 | Sample 8198/9741 | Repeat 3/3 | Reward: 0.150 | Path: people → fear people living in other countries
# 🧪 Epoch 5 | Sample 8199/9741 | Repeat 1/3 | Reward: 0.150 | Path: gallery → display artwork
# 🧪 Epoch 5 | Sample 8199/9741 | Repeat 2/3 | Reward: 0.150 | Path: gallery → display artwork
# 🧪 Epoch 5 | Sample 8199/9741 | Repeat 3/3 | Reward: 0.150 | Path: gallery → display artwork
# 🧪 Epoch 5 | Sample 8200/9741 | Repeat 1/3 | Reward: 0.150 | Path: washing hands → health reasons
# 🧪 Epoch 5 | Sample 8200/9741 | Repeat 2/3 | Reward: 0.150 | Path: washing hands → health reasons
# 🧪 Epoch 5 | Sample 8200/9741 | Repeat 3/3 | Reward: 0.150 | Path: washing hands → health reasons
# 🧪 Epoch 5 | Sample 8201/9741 | Repeat 1/3 | Reward: 0.150 | Path: ocean → depressed areas of earth's surface
# 🧪 Epoch 5 | Sample 8201/9741 | Repeat 2/3 | Reward: 0.150 | Path: ocean → depressed areas of earth's surface
# 🧪 Epoch 5 | Sample 8201/9741 | Repeat 3/3 | Reward: 0.150 | Path: ocean → depressed areas of earth's surface
# 🧪 Epoch 5 | Sample 8202/9741 | Repeat 1/3 | Reward: 0.150 | Path: student → taking up space in classrooms
# 🧪 Epoch 5 | Sample 8202/9741 | Repeat 2/3 | Reward: 0.150 | Path: student → taking up space in classrooms
# 🧪 Epoch 5 | Sample 8202/9741 | Repeat 3/3 | Reward: 0.150 | Path: student → taking up space in classrooms
# 🧪 Epoch 5 | Sample 8203/9741 | Repeat 1/3 | Reward: 0.150 | Path: snake → eat egg
# 🧪 Epoch 5 | Sample 8203/9741 | Repeat 2/3 | Reward: 0.150 | Path: snake → eat egg
# 🧪 Epoch 5 | Sample 8203/9741 | Repeat 3/3 | Reward: 0.150 | Path: snake → eat egg
# 🧪 Epoch 5 | Sample 8204/9741 | Repeat 1/3 | Reward: 0.150 | Path: rest → decrease level of physical activity
# 🧪 Epoch 5 | Sample 8204/9741 | Repeat 2/3 | Reward: 0.150 | Path: rest → decrease level of physical activity
# 🧪 Epoch 5 | Sample 8204/9741 | Repeat 3/3 | Reward: 0.150 | Path: rest → decrease level of physical activity
# 🧪 Epoch 5 | Sample 8205/9741 | Repeat 1/3 | Reward: 0.150 | Path: jumping rope → increase burn of calories
# 🧪 Epoch 5 | Sample 8205/9741 | Repeat 2/3 | Reward: 0.150 | Path: jumping rope → increase burn of calories
# 🧪 Epoch 5 | Sample 8205/9741 | Repeat 3/3 | Reward: 0.150 | Path: jumping rope → increase burn of calories
# 🧪 Epoch 5 | Sample 8206/9741 | Repeat 1/3 | Reward: 0.150 | Path: celebrating → children bounce on beds and furniture
# 🧪 Epoch 5 | Sample 8206/9741 | Repeat 2/3 | Reward: 0.150 | Path: celebrating → excitement prevents normal sleep
# 🧪 Epoch 5 | Sample 8206/9741 | Repeat 3/3 | Reward: 0.150 | Path: celebrating → children bounce on beds and furniture
# 🧪 Epoch 5 | Sample 8207/9741 | Repeat 1/3 | Reward: 0.150 | Path: washing machine → making clothes clean
# 🧪 Epoch 5 | Sample 8207/9741 | Repeat 2/3 | Reward: 0.150 | Path: washing machine → making clothes clean
# 🧪 Epoch 5 | Sample 8207/9741 | Repeat 3/3 | Reward: 0.150 | Path: washing machine → making clothes clean
# 🧪 Epoch 5 | Sample 8208/9741 | Repeat 1/3 | Reward: 0.150 | Path: people → fear people living in other countries
# 🧪 Epoch 5 | Sample 8208/9741 | Repeat 2/3 | Reward: 0.150 | Path: people → fear people living in other countries
# 🧪 Epoch 5 | Sample 8208/9741 | Repeat 3/3 | Reward: 0.150 | Path: people → fear people living in other countries
# 🧪 Epoch 5 | Sample 8209/9741 | Repeat 1/3 | Reward: 0.150 | Path: rain → helpful in natural recycling process
# 🧪 Epoch 5 | Sample 8209/9741 | Repeat 2/3 | Reward: 0.150 | Path: rain → helpful in natural recycling process
# 🧪 Epoch 5 | Sample 8209/9741 | Repeat 3/3 | Reward: 0.150 | Path: rain → helpful in natural recycling process
# 🧪 Epoch 5 | Sample 8210/9741 | Repeat 1/3 | Reward: 0.150 | Path: horse → making fermented mare's milk
# 🧪 Epoch 5 | Sample 8210/9741 | Repeat 2/3 | Reward: 0.150 | Path: horse → making fermented mare's milk
# 🧪 Epoch 5 | Sample 8210/9741 | Repeat 3/3 | Reward: 0.150 | Path: horse → making fermented mare's milk
# 🧪 Epoch 5 | Sample 8211/9741 | Repeat 1/3 | Reward: 0.250 | Path: learn → improve yourself → dress better
# 🧪 Epoch 5 | Sample 8211/9741 | Repeat 2/3 | Reward: 0.250 | Path: learn → improve yourself → dress better
# 🧪 Epoch 5 | Sample 8211/9741 | Repeat 3/3 | Reward: 0.250 | Path: learn → improve yourself → dress better
# 🧪 Epoch 5 | Sample 8212/9741 | Repeat 1/3 | Reward: 0.150 | Path: driving to work → listen to talk show
# 🧪 Epoch 5 | Sample 8212/9741 | Repeat 2/3 | Reward: 0.150 | Path: driving to work → listen to talk show
# 🧪 Epoch 5 | Sample 8212/9741 | Repeat 3/3 | Reward: 0.150 | Path: driving to work → listen to talk show
# 🧪 Epoch 5 | Sample 8213/9741 | Repeat 1/3 | Reward: 0.250 | Path: glad → regret → lead to depression
# 🧪 Epoch 5 | Sample 8213/9741 | Repeat 2/3 | Reward: 0.150 | Path: glad → same as happy
# 🧪 Epoch 5 | Sample 8213/9741 | Repeat 3/3 | Reward: 0.250 | Path: glad → regret → lead to depression
# 🧪 Epoch 5 | Sample 8214/9741 | Repeat 1/3 | Reward: 0.150 | Path: counter → place objects on
# 🧪 Epoch 5 | Sample 8214/9741 | Repeat 2/3 | Reward: 0.150 | Path: counter → place objects on
# 🧪 Epoch 5 | Sample 8214/9741 | Repeat 3/3 | Reward: 0.150 | Path: counter → place objects on
# 🧪 Epoch 5 | Sample 8215/9741 | Repeat 1/3 | Reward: 0.250 | Path: soft → firm → mattress type
# 🧪 Epoch 5 | Sample 8215/9741 | Repeat 2/3 | Reward: 0.385 | Path: soft → harsh → genteel → gender → compare gender role gender identity
# 🧪 Epoch 5 | Sample 8215/9741 | Repeat 3/3 | Reward: 0.250 | Path: soft → firm → mattress type
# 🧪 Epoch 5 | Sample 8216/9741 | Repeat 1/3 | Reward: 0.250 | Path: container cup → storage → protecting fur during warm seasons
# 🧪 Epoch 5 | Sample 8216/9741 | Repeat 2/3 | Reward: 0.250 | Path: container cup → storage → protecting fur during warm seasons
# 🧪 Epoch 5 | Sample 8216/9741 | Repeat 3/3 | Reward: 0.250 | Path: container cup → storage → protecting fur during warm seasons
# 🧪 Epoch 5 | Sample 8217/9741 | Repeat 1/3 | Reward: 0.150 | Path: people → fear people living in other countries
# 🧪 Epoch 5 | Sample 8217/9741 | Repeat 2/3 | Reward: 0.150 | Path: people → fear people living in other countries
# 🧪 Epoch 5 | Sample 8217/9741 | Repeat 3/3 | Reward: 0.150 | Path: people → fear people living in other countries
# 🧪 Epoch 5 | Sample 8218/9741 | Repeat 1/3 | Reward: 0.150 | Path: eyeglasses case → keep lenses from getting scratched
# 🧪 Epoch 5 | Sample 8218/9741 | Repeat 2/3 | Reward: 0.150 | Path: eyeglasses case → keep lenses from getting scratched
# 🧪 Epoch 5 | Sample 8218/9741 | Repeat 3/3 | Reward: 0.150 | Path: eyeglasses case → keep lenses from getting scratched
# 🧪 Epoch 5 | Sample 8219/9741 | Repeat 1/3 | Reward: 0.150 | Path: eating dinner → reducing hunger
# 🧪 Epoch 5 | Sample 8219/9741 | Repeat 2/3 | Reward: 0.150 | Path: eating dinner → reducing hunger
# 🧪 Epoch 5 | Sample 8219/9741 | Repeat 3/3 | Reward: 0.150 | Path: eating dinner → reducing hunger
# 🧪 Epoch 5 | Sample 8220/9741 | Repeat 1/3 | Reward: 0.150 | Path: people → fear people living in other countries
# 🧪 Epoch 5 | Sample 8220/9741 | Repeat 2/3 | Reward: 0.150 | Path: people → fear people living in other countries
# 🧪 Epoch 5 | Sample 8220/9741 | Repeat 3/3 | Reward: 0.150 | Path: people → fear people living in other countries
# 🧪 Epoch 5 | Sample 8221/9741 | Repeat 1/3 | Reward: 0.150 | Path: blowfish → spongebob cartoon
# 🧪 Epoch 5 | Sample 8221/9741 | Repeat 2/3 | Reward: 0.150 | Path: blowfish → spongebob cartoon
# 🧪 Epoch 5 | Sample 8221/9741 | Repeat 3/3 | Reward: 0.150 | Path: blowfish → spongebob cartoon
# 🧪 Epoch 5 | Sample 8222/9741 | Repeat 1/3 | Reward: 0.150 | Path: cat → enjoy yogurt
# 🧪 Epoch 5 | Sample 8222/9741 | Repeat 2/3 | Reward: 0.150 | Path: cat → enjoy yogurt
# 🧪 Epoch 5 | Sample 8222/9741 | Repeat 3/3 | Reward: 0.150 | Path: cat → enjoy yogurt
# 🧪 Epoch 5 | Sample 8223/9741 | Repeat 1/3 | Reward: 0.150 | Path: light → make humans feel comfortable
# 🧪 Epoch 5 | Sample 8223/9741 | Repeat 2/3 | Reward: 0.150 | Path: light → make humans feel comfortable
# 🧪 Epoch 5 | Sample 8223/9741 | Repeat 3/3 | Reward: 0.150 | Path: light → make humans feel comfortable
# 🧪 Epoch 5 | Sample 8224/9741 | Repeat 1/3 | Reward: 0.150 | Path: advertisement → increasing company's profits
# 🧪 Epoch 5 | Sample 8224/9741 | Repeat 2/3 | Reward: 0.150 | Path: advertisement → increasing company's profits
# 🧪 Epoch 5 | Sample 8224/9741 | Repeat 3/3 | Reward: 0.150 | Path: advertisement → increasing company's profits
# 🧪 Epoch 5 | Sample 8225/9741 | Repeat 1/3 | Reward: 0.150 | Path: standing in queue → get sore feet
# 🧪 Epoch 5 | Sample 8225/9741 | Repeat 2/3 | Reward: 0.150 | Path: standing in queue → get sore feet
# 🧪 Epoch 5 | Sample 8225/9741 | Repeat 3/3 | Reward: 0.150 | Path: standing in queue → get sore feet
# 🧪 Epoch 5 | Sample 8226/9741 | Repeat 1/3 | Reward: 0.150 | Path: cargo → ship by sea
# 🧪 Epoch 5 | Sample 8226/9741 | Repeat 2/3 | Reward: 0.150 | Path: cargo → ship by sea
# 🧪 Epoch 5 | Sample 8226/9741 | Repeat 3/3 | Reward: 0.150 | Path: cargo → ship by sea
# 🧪 Epoch 5 | Sample 8227/9741 | Repeat 1/3 | Reward: 0.150 | Path: rocks → continue to fall
# 🧪 Epoch 5 | Sample 8227/9741 | Repeat 2/3 | Reward: 0.150 | Path: rocks → continue to fall
# 🧪 Epoch 5 | Sample 8227/9741 | Repeat 3/3 | Reward: 0.150 | Path: rocks → continue to fall
# 🧪 Epoch 5 | Sample 8228/9741 | Repeat 1/3 | Reward: 0.150 | Path: marmoset → cage at zoo
# ...
# 🧪 Epoch 5 | Sample 9693/9741 | Repeat 1/3 | Reward: 0.549 | Path: hair salon → get hair cut → shorter → short → computer code variable → code expression → source code → programming → fun and rewarding
# 🧪 Epoch 5 | Sample 9693/9741 | Repeat 2/3 | Reward: 0.150 | Path: hair salon → getting hair color changed
# 🧪 Epoch 5 | Sample 9693/9741 | Repeat 3/3 | Reward: 0.549 | Path: hair salon → get hair cut → shorter → short → computer code variable → code expression → source code → programming → fun and rewarding
# 🧪 Epoch 5 | Sample 9694/9741 | Repeat 1/3 | Reward: 0.150 | Path: sloth → sleep all day
# 🧪 Epoch 5 | Sample 9694/9741 | Repeat 2/3 | Reward: 0.150 | Path: sloth → sleep all day
# 🧪 Epoch 5 | Sample 9694/9741 | Repeat 3/3 | Reward: 0.150 | Path: sloth → sleep all day
# 🧪 Epoch 5 | Sample 9695/9741 | Repeat 1/3 | Reward: 0.150 | Path: learning about science → improving world
# 🧪 Epoch 5 | Sample 9695/9741 | Repeat 2/3 | Reward: 0.150 | Path: learning about science → improving world
# 🧪 Epoch 5 | Sample 9695/9741 | Repeat 3/3 | Reward: 0.150 | Path: learning about science → improving world
# 🧪 Epoch 5 | Sample 9696/9741 | Repeat 1/3 | Reward: 0.150 | Path: steak house → satisfying hunger
# 🧪 Epoch 5 | Sample 9696/9741 | Repeat 2/3 | Reward: 0.150 | Path: steak house → satisfying hunger
# 🧪 Epoch 5 | Sample 9696/9741 | Repeat 3/3 | Reward: 0.150 | Path: steak house → satisfying hunger
# 🧪 Epoch 5 | Sample 9697/9741 | Repeat 1/3 | Reward: 0.150 | Path: christian → bring offering
# 🧪 Epoch 5 | Sample 9697/9741 | Repeat 2/3 | Reward: 0.150 | Path: christian → bring offering
# 🧪 Epoch 5 | Sample 9697/9741 | Repeat 3/3 | Reward: 0.150 | Path: christian → bring offering
# 🧪 Epoch 5 | Sample 9698/9741 | Repeat 1/3 | Reward: 0.150 | Path: person → positive environment
# 🧪 Epoch 5 | Sample 9698/9741 | Repeat 2/3 | Reward: 0.150 | Path: person → positive environment
# 🧪 Epoch 5 | Sample 9698/9741 | Repeat 3/3 | Reward: 0.150 | Path: person → positive environment
# 🧪 Epoch 5 | Sample 9699/9741 | Repeat 1/3 | Reward: 0.150 | Path: beaver → make dam
# 🧪 Epoch 5 | Sample 9699/9741 | Repeat 2/3 | Reward: 0.150 | Path: beaver → make dam
# 🧪 Epoch 5 | Sample 9699/9741 | Repeat 3/3 | Reward: 0.150 | Path: beaver → make dam
# 🧪 Epoch 5 | Sample 9700/9741 | Repeat 1/3 | Reward: 0.150 | Path: child → promise to do better
# 🧪 Epoch 5 | Sample 9700/9741 | Repeat 2/3 | Reward: 0.150 | Path: child → promise to do better
# 🧪 Epoch 5 | Sample 9700/9741 | Repeat 3/3 | Reward: 0.150 | Path: child → promise to do better
# 🧪 Epoch 5 | Sample 9701/9741 | Repeat 1/3 | Reward: 0.150 | Path: changing society → improving environment
# 🧪 Epoch 5 | Sample 9701/9741 | Repeat 2/3 | Reward: 0.150 | Path: changing society → improving environment
# 🧪 Epoch 5 | Sample 9701/9741 | Repeat 3/3 | Reward: 0.150 | Path: changing society → improving environment
# 🧪 Epoch 5 | Sample 9702/9741 | Repeat 1/3 | Reward: 0.150 | Path: going to party → laughter at costumes
# 🧪 Epoch 5 | Sample 9702/9741 | Repeat 2/3 | Reward: 0.150 | Path: going to party → laughter at costumes
# 🧪 Epoch 5 | Sample 9702/9741 | Repeat 3/3 | Reward: 0.150 | Path: going to party → laughter at costumes
# 🧪 Epoch 5 | Sample 9703/9741 | Repeat 1/3 | Reward: 0.150 | Path: buying christmas presents → better retail sales
# 🧪 Epoch 5 | Sample 9703/9741 | Repeat 2/3 | Reward: 0.150 | Path: buying christmas presents → better retail sales
# 🧪 Epoch 5 | Sample 9703/9741 | Repeat 3/3 | Reward: 0.150 | Path: buying christmas presents → better retail sales
# 🧪 Epoch 5 | Sample 9704/9741 | Repeat 1/3 | Reward: 0.150 | Path: chatting with friends → smile and laugh
# 🧪 Epoch 5 | Sample 9704/9741 | Repeat 2/3 | Reward: 0.150 | Path: chatting with friends → smile and laugh
# 🧪 Epoch 5 | Sample 9704/9741 | Repeat 3/3 | Reward: 0.150 | Path: chatting with friends → smile and laugh
# 🧪 Epoch 5 | Sample 9705/9741 | Repeat 1/3 | Reward: 0.325 | Path: nature → serene → anxiety → cause one to lose sleep
# 🧪 Epoch 5 | Sample 9705/9741 | Repeat 2/3 | Reward: 0.325 | Path: nature → serene → anxiety → cause one to lose sleep
# 🧪 Epoch 5 | Sample 9705/9741 | Repeat 3/3 | Reward: 0.325 | Path: nature → serene → anxiety → cause one to lose sleep
# 🧪 Epoch 5 | Sample 9706/9741 | Repeat 1/3 | Reward: 0.150 | Path: kissing → increasing sexual arousal
# 🧪 Epoch 5 | Sample 9706/9741 | Repeat 2/3 | Reward: 0.150 | Path: kissing → increasing sexual arousal
# 🧪 Epoch 5 | Sample 9706/9741 | Repeat 3/3 | Reward: 0.150 | Path: kissing → increasing sexual arousal
# 🧪 Epoch 5 | Sample 9707/9741 | Repeat 1/3 | Reward: 0.150 | Path: gaining more land → laugh evily
# 🧪 Epoch 5 | Sample 9707/9741 | Repeat 2/3 | Reward: 0.150 | Path: gaining more land → laugh evily
# 🧪 Epoch 5 | Sample 9707/9741 | Repeat 3/3 | Reward: 0.150 | Path: gaining more land → laugh evily
# 🧪 Epoch 5 | Sample 9708/9741 | Repeat 1/3 | Reward: 0.150 | Path: washing hands → fighting bacteria
# 🧪 Epoch 5 | Sample 9708/9741 | Repeat 2/3 | Reward: 0.150 | Path: washing hands → fighting bacteria
# 🧪 Epoch 5 | Sample 9708/9741 | Repeat 3/3 | Reward: 0.150 | Path: washing hands → fighting bacteria
# 🧪 Epoch 5 | Sample 9709/9741 | Repeat 1/3 | Reward: 0.150 | Path: bowl → hold dry ingredients for baking
# 🧪 Epoch 5 | Sample 9709/9741 | Repeat 2/3 | Reward: 0.150 | Path: bowl → hold dry ingredients for baking
# 🧪 Epoch 5 | Sample 9709/9741 | Repeat 3/3 | Reward: 0.150 | Path: bowl → hold dry ingredients for baking
# 🧪 Epoch 5 | Sample 9710/9741 | Repeat 1/3 | Reward: 0.150 | Path: chatting with friends → smile and laugh
# 🧪 Epoch 5 | Sample 9710/9741 | Repeat 2/3 | Reward: 0.150 | Path: chatting with friends → smile and laugh
# 🧪 Epoch 5 | Sample 9710/9741 | Repeat 3/3 | Reward: 0.150 | Path: chatting with friends → smile and laugh
# 🧪 Epoch 5 | Sample 9711/9741 | Repeat 1/3 | Reward: 0.150 | Path: kingdom → do great things
# 🧪 Epoch 5 | Sample 9711/9741 | Repeat 2/3 | Reward: 0.150 | Path: kingdom → do great things
# 🧪 Epoch 5 | Sample 9711/9741 | Repeat 3/3 | Reward: 0.150 | Path: kingdom → do great things
# 🧪 Epoch 5 | Sample 9712/9741 | Repeat 1/3 | Reward: 0.150 | Path: expressway → supposed to help traffic move faster
# 🧪 Epoch 5 | Sample 9712/9741 | Repeat 2/3 | Reward: 0.150 | Path: expressway → supposed to help traffic move faster
# 🧪 Epoch 5 | Sample 9712/9741 | Repeat 3/3 | Reward: 0.150 | Path: expressway → supposed to help traffic move faster
# 🧪 Epoch 5 | Sample 9713/9741 | Repeat 1/3 | Reward: 0.150 | Path: perform → get stage fright
# 🧪 Epoch 5 | Sample 9713/9741 | Repeat 2/3 | Reward: 0.150 | Path: perform → get stage fright
# 🧪 Epoch 5 | Sample 9713/9741 | Repeat 3/3 | Reward: 0.150 | Path: perform → get stage fright
# 🧪 Epoch 5 | Sample 9714/9741 | Repeat 1/3 | Reward: 0.150 | Path: sky → providing atmosphere
# 🧪 Epoch 5 | Sample 9714/9741 | Repeat 2/3 | Reward: 0.150 | Path: sky → providing atmosphere
# 🧪 Epoch 5 | Sample 9714/9741 | Repeat 3/3 | Reward: 0.150 | Path: sky → providing atmosphere
# 🧪 Epoch 5 | Sample 9715/9741 | Repeat 1/3 | Reward: 0.150 | Path: food → effect of suppressing hunger
# 🧪 Epoch 5 | Sample 9715/9741 | Repeat 2/3 | Reward: 0.150 | Path: food → effect of suppressing hunger
# 🧪 Epoch 5 | Sample 9715/9741 | Repeat 3/3 | Reward: 0.150 | Path: food → effect of suppressing hunger
# 🧪 Epoch 5 | Sample 9716/9741 | Repeat 1/3 | Reward: 0.150 | Path: tourniquet → controlling blood loss
# 🧪 Epoch 5 | Sample 9716/9741 | Repeat 2/3 | Reward: 0.150 | Path: tourniquet → controlling blood loss
# 🧪 Epoch 5 | Sample 9716/9741 | Repeat 3/3 | Reward: 0.150 | Path: tourniquet → controlling blood loss
# 🧪 Epoch 5 | Sample 9717/9741 | Repeat 1/3 | Reward: 0.150 | Path: getting warm → but on more clothes
# 🧪 Epoch 5 | Sample 9717/9741 | Repeat 2/3 | Reward: 0.150 | Path: getting warm → but on more clothes
# 🧪 Epoch 5 | Sample 9717/9741 | Repeat 3/3 | Reward: 0.150 | Path: getting warm → but on more clothes
# 🧪 Epoch 5 | Sample 9718/9741 | Repeat 1/3 | Reward: 0.150 | Path: bread → drying to make stuffing
# 🧪 Epoch 5 | Sample 9718/9741 | Repeat 2/3 | Reward: 0.150 | Path: bread → drying to make stuffing
# 🧪 Epoch 5 | Sample 9718/9741 | Repeat 3/3 | Reward: 0.150 | Path: bread → drying to make stuffing
# 🧪 Epoch 5 | Sample 9719/9741 | Repeat 1/3 | Reward: 0.150 | Path: writing → make plot more interesting
# 🧪 Epoch 5 | Sample 9719/9741 | Repeat 2/3 | Reward: 0.150 | Path: writing → make plot more interesting
# 🧪 Epoch 5 | Sample 9719/9741 | Repeat 3/3 | Reward: 0.150 | Path: writing → make plot more interesting
# 🧪 Epoch 5 | Sample 9720/9741 | Repeat 1/3 | Reward: 0.150 | Path: live life → end up happy
# 🧪 Epoch 5 | Sample 9720/9741 | Repeat 2/3 | Reward: 0.150 | Path: live life → end up happy
# 🧪 Epoch 5 | Sample 9720/9741 | Repeat 3/3 | Reward: 0.150 | Path: live life → end up happy
# 🧪 Epoch 5 | Sample 9721/9741 | Repeat 1/3 | Reward: 0.150 | Path: newspapers → alot of advertising in
# 🧪 Epoch 5 | Sample 9721/9741 | Repeat 2/3 | Reward: 0.150 | Path: newspapers → alot of advertising in
# 🧪 Epoch 5 | Sample 9721/9741 | Repeat 3/3 | Reward: 0.150 | Path: newspapers → alot of advertising in
# 🧪 Epoch 5 | Sample 9722/9741 | Repeat 1/3 | Reward: 0.606 | Path: disability → potential → potent → potential → potent → potential → potent → potential → potent → potential → potent
# 🧪 Epoch 5 | Sample 9722/9741 | Repeat 2/3 | Reward: 0.606 | Path: disability → potential → potent → potential → potent → potential → potent → potential → potent → potential → potent
# 🧪 Epoch 5 | Sample 9722/9741 | Repeat 3/3 | Reward: 0.606 | Path: disability → potential → potent → potential → phenomenon → wonderful → terrible → excellent → bad → beneficial → benefit
# 🧪 Epoch 5 | Sample 9723/9741 | Repeat 1/3 | Reward: 0.250 | Path: curiosity → use television → use remote control unit
# 🧪 Epoch 5 | Sample 9723/9741 | Repeat 2/3 | Reward: 0.250 | Path: curiosity → use television → use remote control unit
# 🧪 Epoch 5 | Sample 9723/9741 | Repeat 3/3 | Reward: 0.250 | Path: curiosity → use television → use remote control unit
# 🧪 Epoch 5 | Sample 9724/9741 | Repeat 1/3 | Reward: 0.150 | Path: hurting else → apologizing for inappropriate behavior
# 🧪 Epoch 5 | Sample 9724/9741 | Repeat 2/3 | Reward: 0.150 | Path: hurting else → apologizing for inappropriate behavior
# 🧪 Epoch 5 | Sample 9724/9741 | Repeat 3/3 | Reward: 0.150 | Path: hurting else → apologizing for inappropriate behavior
# 🧪 Epoch 5 | Sample 9725/9741 | Repeat 1/3 | Reward: 0.150 | Path: cloud → regulating temperatures in region
# 🧪 Epoch 5 | Sample 9725/9741 | Repeat 2/3 | Reward: 0.150 | Path: cloud → regulating temperatures in region
# 🧪 Epoch 5 | Sample 9725/9741 | Repeat 3/3 | Reward: 0.150 | Path: cloud → regulating temperatures in region
# 🧪 Epoch 5 | Sample 9726/9741 | Repeat 1/3 | Reward: 0.606 | Path: puzzle → enjoying → enjoy → dislike → disapprove → approve → disapprove → approve → disapprove → approve → disapprove
# 🧪 Epoch 5 | Sample 9726/9741 | Repeat 2/3 | Reward: 0.606 | Path: puzzle → enjoying → enjoy → dislike → disapprove → approve → disapprove → approve → disapprove → approve → disapprove
# 🧪 Epoch 5 | Sample 9726/9741 | Repeat 3/3 | Reward: 0.606 | Path: puzzle → enjoying → enjoy → dislike → disapprove → approve → disapprove → approve → disapprove → approve → disapprove
# 🧪 Epoch 5 | Sample 9727/9741 | Repeat 1/3 | Reward: 0.250 | Path: science → nanotechnology → very important
# 🧪 Epoch 5 | Sample 9727/9741 | Repeat 2/3 | Reward: 0.250 | Path: science → nanotechnology → very important
# 🧪 Epoch 5 | Sample 9727/9741 | Repeat 3/3 | Reward: 0.250 | Path: science → nanotechnology → very important
# 🧪 Epoch 5 | Sample 9728/9741 | Repeat 1/3 | Reward: 0.150 | Path: fish → return home
# 🧪 Epoch 5 | Sample 9728/9741 | Repeat 2/3 | Reward: 0.150 | Path: fish → return home
# 🧪 Epoch 5 | Sample 9728/9741 | Repeat 3/3 | Reward: 0.150 | Path: fish → return home
# 🧪 Epoch 5 | Sample 9729/9741 | Repeat 1/3 | Reward: 0.150 | Path: watch film → experience fright
# 🧪 Epoch 5 | Sample 9729/9741 | Repeat 2/3 | Reward: 0.150 | Path: watch film → leave theatre
# 🧪 Epoch 5 | Sample 9729/9741 | Repeat 3/3 | Reward: 0.150 | Path: watch film → experience fright
# 🧪 Epoch 5 | Sample 9730/9741 | Repeat 1/3 | Reward: 0.150 | Path: writing term paper → demonstrating competence
# 🧪 Epoch 5 | Sample 9730/9741 | Repeat 2/3 | Reward: 0.150 | Path: writing term paper → demonstrating competence
# 🧪 Epoch 5 | Sample 9730/9741 | Repeat 3/3 | Reward: 0.150 | Path: writing term paper → demonstrating competence
# 🧪 Epoch 5 | Sample 9731/9741 | Repeat 1/3 | Reward: 0.150 | Path: steam → more energy than liquid water
# 🧪 Epoch 5 | Sample 9731/9741 | Repeat 2/3 | Reward: 0.150 | Path: steam → more energy than liquid water
# 🧪 Epoch 5 | Sample 9731/9741 | Repeat 3/3 | Reward: 0.150 | Path: steam → more energy than liquid water
# 🧪 Epoch 5 | Sample 9732/9741 | Repeat 1/3 | Reward: 0.150 | Path: surface → interfacing with another surface
# 🧪 Epoch 5 | Sample 9732/9741 | Repeat 2/3 | Reward: 0.150 | Path: surface → interfacing with another surface
# 🧪 Epoch 5 | Sample 9732/9741 | Repeat 3/3 | Reward: 0.150 | Path: surface → interfacing with another surface
# 🧪 Epoch 5 | Sample 9733/9741 | Repeat 1/3 | Reward: 0.150 | Path: board game → provide alternative to tv
# 🧪 Epoch 5 | Sample 9733/9741 | Repeat 2/3 | Reward: 0.150 | Path: board game → provide alternative to tv
# 🧪 Epoch 5 | Sample 9733/9741 | Repeat 3/3 | Reward: 0.150 | Path: board game → provide alternative to tv
# 🧪 Epoch 5 | Sample 9734/9741 | Repeat 1/3 | Reward: 0.250 | Path: seating → theatre → show cartoon
# 🧪 Epoch 5 | Sample 9734/9741 | Repeat 2/3 | Reward: 0.250 | Path: seating → theatre → show cartoon
# 🧪 Epoch 5 | Sample 9734/9741 | Repeat 3/3 | Reward: 0.250 | Path: seating → theatre → show cartoon
# 🧪 Epoch 5 | Sample 9735/9741 | Repeat 1/3 | Reward: 0.150 | Path: attic → storing seldom used things in house
# 🧪 Epoch 5 | Sample 9735/9741 | Repeat 2/3 | Reward: 0.150 | Path: attic → storing seldom used things in house
# 🧪 Epoch 5 | Sample 9735/9741 | Repeat 3/3 | Reward: 0.150 | Path: attic → storing seldom used things in house
# 🧪 Epoch 5 | Sample 9736/9741 | Repeat 1/3 | Reward: 0.150 | Path: opening business → entering into competition with other businesses
# 🧪 Epoch 5 | Sample 9736/9741 | Repeat 2/3 | Reward: 0.150 | Path: opening business → anxiety because most businesses fail
# 🧪 Epoch 5 | Sample 9736/9741 | Repeat 3/3 | Reward: 0.150 | Path: opening business → anxiety because most businesses fail
# 🧪 Epoch 5 | Sample 9737/9741 | Repeat 1/3 | Reward: 0.150 | Path: going public → making more money for company
# 🧪 Epoch 5 | Sample 9737/9741 | Repeat 2/3 | Reward: 0.150 | Path: going public → making more money for company
# 🧪 Epoch 5 | Sample 9737/9741 | Repeat 3/3 | Reward: 0.150 | Path: going public → making more money for company
# 🧪 Epoch 5 | Sample 9738/9741 | Repeat 1/3 | Reward: 0.150 | Path: chair → better than what use
# 🧪 Epoch 5 | Sample 9738/9741 | Repeat 2/3 | Reward: 0.150 | Path: chair → better than what use
# 🧪 Epoch 5 | Sample 9738/9741 | Repeat 3/3 | Reward: 0.150 | Path: chair → better than what use
# 🧪 Epoch 5 | Sample 9739/9741 | Repeat 1/3 | Reward: 0.150 | Path: jeans → protect legs
# 🧪 Epoch 5 | Sample 9739/9741 | Repeat 2/3 | Reward: 0.150 | Path: jeans → protect legs
# 🧪 Epoch 5 | Sample 9739/9741 | Repeat 3/3 | Reward: 0.150 | Path: jeans → protect legs
# 🧪 Epoch 5 | Sample 9740/9741 | Repeat 1/3 | Reward: 0.385 | Path: well → wishing → wish → express → favorite of all stores
# 🧪 Epoch 5 | Sample 9740/9741 | Repeat 2/3 | Reward: 0.385 | Path: well → wishing → wish → express → favorite of all stores
# 🧪 Epoch 5 | Sample 9740/9741 | Repeat 3/3 | Reward: 0.385 | Path: well → wishing → wish → express → favorite of all stores
# 🧪 Epoch 5 | Sample 9741/9741 | Repeat 1/3 | Reward: 0.150 | Path: electricity → kill if used improperly
# 🧪 Epoch 5 | Sample 9741/9741 | Repeat 2/3 | Reward: 0.150 | Path: electricity → kill if used improperly
# 🧪 Epoch 5 | Sample 9741/9741 | Repeat 3/3 | Reward: 0.150 | Path: electricity → kill if used improperly
#
# ✅ Saved 10301 successful reasoning paths to '/content/drive/MyDrive/ABC/KnowGPT/extracted_train_paths.pkl'

# %%
# === Save results ===
with open(EXTRACTED_TRAIN_PATH, "wb") as f:
    pickle.dump(results, f)
print(f"\n✅ Saved {len(results)} successful reasoning paths to '{EXTRACTED_TRAIN_PATH}'")
# Out:
# ✅ Saved 10301 successful reasoning paths to '/content/drive/MyDrive/ABC/KnowGPT/extracted_train_paths_v3.pkl'

# %%
import pickle

with open(EXTRACTED_TRAIN_PATH, "rb") as f:
    results = pickle.load(f)

print(f"✅ Loaded {len(results)} reasoning paths")

from random import sample

for r in sample(results, 3):  # In 3 mẫu ngẫu nhiên
    print(r)
    print("🔍 Episode:", r["epoch"])
    print("Question:", r["question_text"])
    print("Source:", r["source"])
    print("Target:", r["target"])
    print("Path:", " → ".join(r["path"]))
    print("Reward:", round(r["reward"], 4))
    print("-" * 60)
# Out:
# ✅ Loaded 10301 reasoning paths
# {'epoch': 2, 'question_id': '02196c3c0d4932144624d0f803e0d47d', 'question_text': 'Where could you find ticket office that are all of the same type?', 'source': 'ticket office', 'target': 'movie theaters', 'path': ['ticket office', 'movie theaters'], 'reward': 1.15, 'steps': 2}
# 🔍 Episode: 2
# Question: Where could you find ticket office that are all of the same type?
# Source: ticket office
# Target: movie theaters
# Path: ticket office → movie theaters
# Reward: 1.15
# ------------------------------------------------------------
# {'epoch': 4, 'question_id': 'd8404dc56727b89499c186c3f74bf8e3', 'question_text': "Where did he put the newspaper for his new puppy's leaks?", 'source': 'newspaper', 'target': 'floor', 'path': ['newspaper', 'motivate', 'demotivate', 'motivate', 'demotivate', 'motivate', 'demotivate', 'motivate', 'demotivate', 'motivate', 'demotivate'], 'reward': 0.6059632034632034, 'steps': 11}
# 🔍 Episode: 4
# Question: Where did he put the newspaper for his new puppy's leaks?
# Source: newspaper
# Target: floor
# Path: newspaper → motivate → demotivate → motivate → demotivate → motivate → demotivate → motivate → demotivate → motivate → demotivate
# Reward: 0.606
# ------------------------------------------------------------
# {'epoch': 4, 'question_id': '7d1c8769ba1e4122cd2987e6a3200b9e', 'question_text': 'Sam thought that it was beautiful outside, even though it was what?', 'source': 'beautiful', 'target': 'rainy', 'path': ['beautiful', 'bad', 'beneficial', 'benefit', 'disadvantage', 'advantage', 'disadvantage', 'advantage', 'disadvantage', 'advantage', 'disadvantage'], 'reward': 0.6059632034632034, 'steps': 11}
# 🔍 Episode: 4
# Question: Sam thought that it was beautiful outside, even though it was what?
# Source: beautiful
# Target: rainy
# Path: beautiful → bad → beneficial → benefit → disadvantage → advantage → disadvantage → advantage → disadvantage → advantage → disadvantage
# Reward: 0.606
# ------------------------------------------------------------

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# # Train MAB

# %% [markdown]
# **Bổ sung A, B, C, D vào lựa chọn**

# %%
qid2sample = {s['question_id']: s for s in samples}

for r in results:
    if 'correct_answer' not in r and r['question_id'] in qid2sample:
        s = qid2sample[r['question_id']]
        r['correct_answer'] = s['correct_answer']
        r['options'] = s['options']

print(random.choice(samples))
# Out:
# {'question_id': 'a14f9b20745fe43422438698c88f89d7', 'question_text': 'A tabby cat might be found laying where?', 'options': ['home', 'pet shop', 'lap', 'dog pound', 'alley'], 'correct_answer': 'lap', 'correct_answer_label': 'C', 'source_entities': ['tabby cat'], 'target_entity': 'lap'}

# %%
API_KEY = None

# %%
import numpy as np
import random
from collections import defaultdict
import pandas as pd
from openai import OpenAI

class PromptConstructorMAB:
    def __init__(self, templates, temperature=1.0):
        self.templates = templates
        self.template_names = list(templates.keys())
        self.counts = defaultdict(int)
        self.successes = defaultdict(int)
        self.temperature = temperature

    def select_template(self):
        if all(self.counts[name] == 0 for name in self.template_names):
            return random.choice(self.template_names)

        rates = np.array([
            self.successes[name] / self.counts[name] if self.counts[name] > 0 else 0
            for name in self.template_names
        ])
        probs = np.exp(rates / self.temperature)
        probs /= np.sum(probs)
        return np.random.choice(self.template_names, p=probs)

    def record_feedback(self, template_name, reward):
        self.counts[template_name] += 1
        self.successes[template_name] += reward

    def format_prompt(self, question_text, paths, template_name, options):
        return self.templates[template_name](question_text, paths, options)

    def reset(self):
        self.counts.clear()
        self.successes.clear()

# === Prompt Templates ===
def template_triples(question, paths, options):
    lines = []
    for path in paths:
        triples = [f"({path[i]} → {path[i+1]})" for i in range(len(path)-1)]
        lines.append("\n".join(triples))
    opt_lines = [f"{chr(65+i)}. {opt}" for i, opt in enumerate(options)]
    prompt = (
        f"Question: {question}\n"
        + "Options:\n" + "\n".join(opt_lines) + "\n"
        + "Knowledge:\n" + "\n\n".join(lines)
    )
    return prompt

def template_sentence(question, paths, options):
    sentences = [" → ".join(path) for path in paths]
    opt_lines = [f"{chr(65+i)}. {opt}" for i, opt in enumerate(options)]
    prompt = (
        f"Question: {question}\n"
        + "Options:\n" + "\n".join(opt_lines) + "\n"
        + "Context:\n" + "\n\n".join(sentences)
    )
    return prompt

def template_graph_summary(question, paths, options):
    summaries = [f"The concept '{path[0]}' leads through {len(path)} steps to '{path[-1]}'" for path in paths]
    opt_lines = [f"{chr(65+i)}. {opt}" for i, opt in enumerate(options)]
    prompt = (
        f"Question: {question}\n"
        + "Options:\n" + "\n".join(opt_lines) + "\n"
        + "Summary:\n" + "\n\n".join(summaries)
    )
    return prompt

# === Enhanced Templates (v2) ===
def template_sentence_v2(question, paths, options):
    intro = (
        "You are solving a commonsense multiple-choice question.\n"
        "You are given a question, a list of options, and one or more reasoning paths connecting related concepts.\n"
        "Use the context below to determine the most likely answer.\n\n"
    )
    opt_lines = [f"{chr(65+i)}. {opt}" for i, opt in enumerate(options)]
    sentences = [f"Reasoning Path #{i+1}: " + " → ".join(path) for i, path in enumerate(paths)]
    prompt = (
        intro
        + f"Question: {question}\n"
        + "Options:\n" + "\n".join(opt_lines) + "\n\n"
        + "Context:\n" + "\n".join(sentences) + "\n\n"
        + "Please select the best option (A-E) based on the reasoning above."
    )
    return prompt

def template_triples_v2(question, paths, options):
    intro = (
        "You are solving a knowledge-based reasoning task.\n"
        "Each reasoning path is represented by a sequence of knowledge triples.\n"
        "Use the triples and select the best answer.\n\n"
    )
    lines = []
    for i, path in enumerate(paths):
        triples = [f"({path[j]} → {path[j+1]})" for j in range(len(path)-1)]
        lines.append(f"Path {i+1}:\n" + "\n".join(triples))
    opt_lines = [f"{chr(65+i)}. {opt}" for i, opt in enumerate(options)]
    prompt = (
        intro +
        f"Question: {question}\n"
        + "Options:\n" + "\n".join(opt_lines) + "\n\n"
        + "Knowledge Paths:\n" + "\n\n".join(lines)
    )
    return prompt

def template_graph_summary_v2(question, paths, options):
    intro = (
        "You are solving a high-level reasoning problem.\n"
        "Each path provides a summary from one concept to another.\n"
        "Use these summaries to determine the correct answer.\n\n"
    )
    summaries = [f"Summary {i+1}: The concept '{p[0]}' is connected through {len(p)-1} steps to '{p[-1]}'" for i, p in enumerate(paths)]
    opt_lines = [f"{chr(65+i)}. {opt}" for i, opt in enumerate(options)]
    prompt = (
        intro +
        f"Question: {question}\n"
        + "Options:\n" + "\n".join(opt_lines) + "\n\n"
        + "Reasoning Summaries:\n" + "\n\n".join(summaries)
    )
    return prompt

TEMPLATE_FUNCS = {
    "triples": template_triples,
    "sentence": template_sentence,
    "summary": template_graph_summary,
    # "sentence_v2": template_sentence_v2,
    # "triples_v2": template_triples_v2,
    # "summary_v2": template_graph_summary_v2
}

# %%
# === Simulate or call GPT model ===
def simulate_fn_gpt(prompt, correct_answer, options, model_name="gpt-4-turbo"):
    api_key = API_KEY
    client = OpenAI(api_key=api_key)

    system_prompt = (
        "You are a multiple-choice QA system.\n"
        "Only respond with the letter corresponding to your chosen answer (e.g., A, B, C, D, or E).\n"
        "Do not include the answer text."
    )

    try:
        print("\n🟢 [DEBUG] Sending to GPT...")
        print("Prompt:\n", prompt)

        response = client.chat.completions.create(
            model=model_name,
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": prompt}
            ],
            temperature=0.3,
            max_tokens=1,
        )

        prediction = response.choices[0].message.content.strip().upper()

        label_map = {chr(65 + i): opt.strip().lower() for i, opt in enumerate(options)}
        correct_text = correct_answer.strip().lower()
        predicted_text = label_map.get(prediction, "")

        reward = int(predicted_text == correct_text)

        print("GPT Answer:", prediction)
        print("Mapped to:", predicted_text)
        print("Correct:", correct_text)
        print("Reward:", reward)

        return reward, prediction

    except Exception as e:
        print("❌ GPT error:", e)
        return 0, "ERROR"

# === Phase 2 Evaluation Loop ===
def train_mab_on_data(results, mab, simulate_fn, max_samples=100, top_k_paths=3):
    total = 0
    correct = 0
    log = []

    sampled = random.sample(results, min(len(results), max_samples))

    for idx, r in enumerate(sampled):
        if "correct_answer" not in r or "options" not in r:
            continue

        all_paths = r.get("paths", [r['path']])
        selected_paths = all_paths[:top_k_paths] if len(all_paths) >= top_k_paths else all_paths

        template_name = mab.select_template()
        prompt = mab.format_prompt(r['question_text'], selected_paths, template_name, r['options'])

        print(f"\n📚 [{idx+1}] Template: {template_name}, QID: {r['question_id']}, Path len: {len(selected_paths)}")

        reward, prediction = simulate_fn(prompt, r['correct_answer'], r['options'])
        mab.record_feedback(template_name, reward)

        total += 1
        correct += reward

        log.append({
            "template": template_name,
            "question_id": r['question_id'],
            "prompt": prompt,
            "predicted": prediction,
            "correct": r['correct_answer'],
            "reward": reward
        })

    acc = correct / total if total else 0.0
    return acc, log

# === Extra: Print Top Prompts ===
def print_top_prompts(log, top_k=5):
    good_prompts = [x for x in log if x['reward'] == 1]
    sorted_prompts = sorted(good_prompts, key=lambda x: len(x['prompt']))[:top_k]
    for i, entry in enumerate(sorted_prompts):
        print(f"--- Top Prompt #{i+1} ---")
        print(entry['prompt'])
        print("Prediction:", entry['predicted'])
        print("Correct:", entry['correct'])
        print()

# === Extra: Template Stats ===
def print_template_statistics(log):
    stats = defaultdict(lambda: [0, 0])  # {template: [correct, total]}
    for row in log:
        stats[row['template']][0] += row['reward']
        stats[row['template']][1] += 1
    print("\nTemplate Statistics:")
    for k, (c, t) in stats.items():
        acc = c / t if t > 0 else 0.0
        print(f"  {k}: {acc:.3f} ({c}/{t})")

# === Extra: Save to CSV ===
def save_log_csv(log, path="mab_eval_log.csv"):
    df = pd.DataFrame(log)
    df.to_csv(path, index=False)
    print(f"✅ Log saved to {path}")

# %% [markdown]
# **Thử nhiệm FeedBack của ChatGPT3.5**

# %%
mab = PromptConstructorMAB(TEMPLATE_FUNCS)

# %%
import random

# Chọn một sample ngẫu nhiên từ kết quả đã train
sample = random.choice([r for r in results if 'correct_answer' in r and 'options' in r])

paths = sample.get("paths", [sample["path"]])[:3]
template_name = mab.select_template()

prompt = mab.format_prompt(
    question_text=sample["question_text"],
    paths=paths,
    template_name=template_name,
    options=sample["options"]
)

reward, prediction = simulate_fn_gpt(prompt, sample["correct_answer"], sample["options"])
mab.record_feedback(template_name, reward)

print("📌 Template:", template_name)
print("❓ Question:", sample['question_text'])
print("🔢 Options:", sample['options'])
print("📍 Path:", " → ".join(sample["path"]))
print("\n📋 Prompt:\n", prompt)
print("🤖 GPT Prediction:", prediction)
print("✅ Correct Answer:", sample['correct_answer'])
print("🎯 Reward:", reward)
# Out:
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: A John is a bum.  Much like the stereotype, he lives near this sort of transportation infrastructure. Where does he live?
# Options:
# A. bus depot
# B. beach
# C. train station
# D. bridge
# E. bridge
# Summary:
# The concept 'bum' leads through 11 steps to 'productive'
# GPT Answer: D
# Mapped to: bridge
# Correct: bridge
# Reward: 1
# 📌 Template: summary
# ❓ Question: A John is a bum.  Much like the stereotype, he lives near this sort of transportation infrastructure. Where does he live?
# 🔢 Options: ['bus depot', 'beach', 'train station', 'bridge', 'bridge']
# 📍 Path: bum → chintzy → chinchy → stingy → miserly → avaricious → greedy → nongreedy → greedy → lazy → productive
#
# 📋 Prompt:
#  Question: A John is a bum.  Much like the stereotype, he lives near this sort of transportation infrastructure. Where does he live?
# Options:
# A. bus depot
# B. beach
# C. train station
# D. bridge
# E. bridge
# Summary:
# The concept 'bum' leads through 11 steps to 'productive'
# 🤖 GPT Prediction: D
# ✅ Correct Answer: bridge
# 🎯 Reward: 1

# %% [markdown]
# **Train MAB**

# %%
acc, log = train_mab_on_data(results, mab, simulate_fn_gpt, max_samples=500, top_k_paths=3)
# Out:
# Streaming output truncated to the last 5000 lines.
# (irreverence → reverence)
# (reverence → irreverence)
# (irreverence → reverence)
# (reverence → irreverence)
# (irreverence → reverence)
# (reverence → irreverence)
# (irreverence → reverence)
# (reverence → irreverence)
# (irreverence → reverence)
# GPT Answer: C
# Mapped to: ignoring
# Correct: ignoring
# Reward: 1
#
# 📚 [248] Template: sentence, QID: 06748592fa4f35f3eeba6352e2bc1a35, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: The teacher encouraged note taking because everything was important, but it turned out the information that day was what for the upcoming quiz?
# Options:
# A. insignificant
# B. off
# C. trivial
# D. ignorable
# E. useless
# Context:
# important → negligible → significant → negligible → significant → negligible → significant → negligible → significant → negligible → significant
# GPT Answer: A
# Mapped to: insignificant
# Correct: useless
# Reward: 0
#
# 📚 [249] Template: sentence, QID: 1abced44a4678d8add27e52f2a4164c7, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Making the cars made a lot of noise, everybody had to wear earplugs at the what?
# Options:
# A. factory
# B. mall
# C. classroom
# D. carnival
# E. big city
# Context:
# noise → blaring → blare → noise → blaring → blare → noise → blaring → blare → noise → blaring
# GPT Answer: A
# Mapped to: factory
# Correct: factory
# Reward: 1
#
# 📚 [250] Template: triples, QID: db763313602729c5cd603024f948ca39, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: There is very little original art these days.  How might most art be described?
# Options:
# A. copy
# B. derivative
# C. reproduction
# D. simile
# E. internet
# Knowledge:
# (original → derivative)
# GPT Answer: B
# Mapped to: derivative
# Correct: derivative
# Reward: 1
#
# 📚 [251] Template: summary, QID: 348d5f52010eb21a8db7659b5968edae, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: What is a person that is not from the east?
# Options:
# A. north
# B. westerly
# C. eastside
# D. westward
# E. western
# Summary:
# The concept 'east' leads through 2 steps to 'western'
# GPT Answer: E
# Mapped to: western
# Correct: western
# Reward: 1
#
# 📚 [252] Template: sentence, QID: 609379b5cd23ae006b6ef29a8fb9ae88, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: What in a car could have an led?
# Options:
# A. electronics
# B. dashboard
# C. electronic equipment
# D. display
# E. pc board
# Context:
# led → display panel → display → demonstrate → suggest → demonstrate → suggest → demonstrate → suggest → demonstrate → suggest
# GPT Answer: D
# Mapped to: display
# Correct: dashboard
# Reward: 0
#
# 📚 [253] Template: triples, QID: 93f37a3cabe0c30c0cad59bdf19f9400, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: What is the opposite of a village?
# Options:
# A. rural area
# B. africa
# C. ohio
# D. big city
# E. tribe
# Knowledge:
# (village → big city)
# GPT Answer: D
# Mapped to: big city
# Correct: big city
# Reward: 1
#
# 📚 [254] Template: triples, QID: fb9c3005d6d7dbf9c6f63348a44bd110, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Where was there never any mammoth?
# Options:
# A. wild
# B. north dakota
# C. forest
# D. movie
# E. zoo
# Knowledge:
# (mammoth → zoo)
# GPT Answer: E
# Mapped to: zoo
# Correct: zoo
# Reward: 1
#
# 📚 [255] Template: summary, QID: 1c304572d38df2e510f3f19a99faa325, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Beautiful lightning strikes happen on what kind of day?
# Options:
# A. november
# B. rainy
# C. dull
# D. wet
# E. average
# Summary:
# The concept 'beautiful' leads through 11 steps to 'disadvantage'
# GPT Answer: B
# Mapped to: rainy
# Correct: rainy
# Reward: 1
#
# 📚 [256] Template: sentence, QID: 1c881efa254bcc6167c15b69a7e21a72, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: You can put what next to a side chair to make a nice place to read and drink coffee?
# Options:
# A. office
# B. library
# C. table
# D. building
# E. coffee shop
# Context:
# side chair → table
# GPT Answer: C
# Mapped to: table
# Correct: table
# Reward: 1
#
# 📚 [257] Template: summary, QID: c3ce06c4144c4e0434752ca8597cd7be, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: He never got in trouble, he received a certificate for what?
# Options:
# A. safe
# B. park
# C. calm
# D. being good
# E. good behavior
# Summary:
# The concept 'trouble' leads through 2 steps to 'good behavior'
# GPT Answer: E
# Mapped to: good behavior
# Correct: good behavior
# Reward: 1
#
# 📚 [258] Template: sentence, QID: 7a8d618dd620820ba308c774a57f76e4_1, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: The temperature was such that one could see their breath, what was occuring?
# Options:
# A. increase
# B. drop rapidly
# C. drop to zero
# D. mist
# E. heat up
# Context:
# temperature → drop to zero
# GPT Answer: C
# Mapped to: drop to zero
# Correct: drop to zero
# Reward: 1
#
# 📚 [259] Template: triples, QID: c35aa9b6fe9ab5f0a40bc45f6a04aaf0, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: The mountain was very massive.  It did what to the nearby hills?
# Options:
# A. lame
# B. insubstantial
# C. inconsequential
# D. dwarf
# E. massless
# Knowledge:
# (massive → dwarf)
# GPT Answer: D
# Mapped to: dwarf
# Correct: dwarf
# Reward: 1
#
# 📚 [260] Template: sentence, QID: 4a463ca5b3485d87e256f287feb96128, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: What is something not optional, that I have to do?
# Options:
# A. obligatory
# B. mandatory
# C. required
# D. selective
# E. compulsory
# Context:
# optional → option → optimism → pessimism → optimism → pessimism → optimism → pessimism → optimism → pessimism → optimism
# GPT Answer: B
# Mapped to: mandatory
# Correct: obligatory
# Reward: 0
#
# 📚 [261] Template: sentence, QID: efe6257866abfd5618c30928fbc619a4, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: He never used window cleaner on his screen, he had heard it wasn't good for cleaning his computer's what?
# Options:
# A. theatre
# B. movies
# C. drive in movie
# D. monitor
# E. closet
# Context:
# screen → monitor
# GPT Answer: D
# Mapped to: monitor
# Correct: monitor
# Reward: 1
#
# 📚 [262] Template: triples, QID: cbc721219ab43cee557dadec468e919c, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: How would one describe the effects of a hurricane?
# Options:
# A. horrendous
# B. disaster
# C. bring destruction
# D. tornadoes
# E. tremendous
# Knowledge:
# (hurricane → atlantic ocean)
# (atlantic ocean → western hemisphere)
# (western hemisphere → western hemisphere)
# (western hemisphere → western hemisphere)
# (western hemisphere → western hemisphere)
# (western hemisphere → western hemisphere)
# (western hemisphere → western hemisphere)
# (western hemisphere → western hemisphere)
# (western hemisphere → western hemisphere)
# (western hemisphere → western hemisphere)
# GPT Answer: C
# Mapped to: bring destruction
# Correct: horrendous
# Reward: 0
#
# 📚 [263] Template: summary, QID: 647445d90d61d4ff6202555d13c3af34, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Where does someone keep their favorite text?
# Options:
# A. book store
# B. newspaper
# C. library
# D. own home
# E. novel
# Summary:
# The concept 'text' leads through 2 steps to 'own home'
# GPT Answer: D
# Mapped to: own home
# Correct: own home
# Reward: 1
#
# 📚 [264] Template: sentence, QID: 5319ac0fc978e07ec2af8a6da45876dc, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: They would strike at night, the order to rise was given when?
# Options:
# A. sundown
# B. fall
# C. sunset
# D. manual
# E. go down
# Context:
# rise → reduce → restrict → restrict → restrict → prevent → allow → forbid → allow → prohibit → forbid
# GPT Answer: C
# Mapped to: sunset
# Correct: sundown
# Reward: 0
#
# 📚 [265] Template: triples, QID: 9b4c6ad13b3ac91b9f4238ab64d9e0af, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: What business serves alcoholic refreshment?
# Options:
# A. church
# B. homeless shelter
# C. prison
# D. bar
# E. park
# Knowledge:
# (alcoholic → homeless shelter)
# (homeless shelter → homeless)
# (homeless → less)
# (less → greater)
# (greater → lesser)
# (lesser → greater)
# (greater → lesser)
# (lesser → greater)
# (greater → lesser)
# (lesser → greater)
# GPT Answer: D
# Mapped to: bar
# Correct: bar
# Reward: 1
#
# 📚 [266] Template: triples, QID: d13185ac565811fbc972b9214e2fd76e, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Where might a person go if they need urgent care for a wound?
# Options:
# A. body
# B. injury
# C. patient
# D. emergency room
# E. hospital
# Knowledge:
# (wound → emergency room)
# GPT Answer: D
# Mapped to: emergency room
# Correct: emergency room
# Reward: 1
#
# 📚 [267] Template: summary, QID: f1f74a41bfe1ff16bfb23617e22b25e4, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: antarctic ocean is named after a continent.  What's another ocean that's named after a landmass?
# Options:
# A. antarctic
# B. atlantic
# C. pacific
# D. indian ocean
# E. pacific
# Summary:
# The concept 'antarctic ocean' leads through 2 steps to 'indian ocean'
# GPT Answer: D
# Mapped to: indian ocean
# Correct: indian ocean
# Reward: 1
#
# 📚 [268] Template: triples, QID: f8282e2d459bf9c2613da0474a1134d9, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Simon was meeting Jane that afternoon.  This meant that he needed to be finished with his project by when?
# Options:
# A. evening
# B. before lunch
# C. after
# D. morning
# E. after
# Knowledge:
# (afternoon → before lunch)
# GPT Answer: B
# Mapped to: before lunch
# Correct: before lunch
# Reward: 1
#
# 📚 [269] Template: summary, QID: 25f24bf27c62f862f9d01a86b77dab48, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Billy was a solider.  He joined the military because he wanted to do what?
# Options:
# A. to marry
# B. fight for freedom
# C. report for duty
# D. wait for orders
# E. receive orders
# Summary:
# The concept 'soldier' leads through 11 steps to 'efficiency'
# GPT Answer: B
# Mapped to: fight for freedom
# Correct: fight for freedom
# Reward: 1
#
# 📚 [270] Template: sentence, QID: 3e97a76512178d271a1c3532c0e628d2, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Jane was beautiful on the inside, but on the outside she wasn't much to look at.  How might she be described?
# Options:
# A. sleepy
# B. homely
# C. misshapen
# D. bad
# E. overcast
# Context:
# beautiful → average → poor → adequate → inadequate → unsuitable → suitable → unsuitable → suitable → unsuitable → suitable
# GPT Answer: B
# Mapped to: homely
# Correct: homely
# Reward: 1
#
# 📚 [271] Template: sentence, QID: 7a7431917d93f095c71a9ee81350654a, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: The anemone was being harvested for sale in New York, where was it likely taken from?
# Options:
# A. tide pool
# B. nursery
# C. michigan
# D. atlantic ocean
# E. ocean floor
# Context:
# anemone → greenhouse → glasshouse → greenhouse → glasshouse → greenhouse → glasshouse → greenhouse → glasshouse → greenhouse → glasshouse
# GPT Answer: A
# Mapped to: tide pool
# Correct: atlantic ocean
# Reward: 0
#
# 📚 [272] Template: summary, QID: 8446115d731024f6bd11810ac86329ab, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: James is eloquent, usually.  Today he was just doing what to himself?
# Options:
# A. speechless
# B. voiceless
# C. screaming
# D. stumbling
# E. muttering
# Summary:
# The concept 'eloquent' leads through 11 steps to 'hesitate'
# GPT Answer: E
# Mapped to: muttering
# Correct: muttering
# Reward: 1
#
# 📚 [273] Template: sentence, QID: 822cb3fdab7987cf88fc166c9b2c4f4c, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Where is pavement usually found?
# Options:
# A. ground
# B. town
# C. city block
# D. a race track
# E. driveway
# Context:
# pavement → ground
# GPT Answer: A
# Mapped to: ground
# Correct: ground
# Reward: 1
#
# 📚 [274] Template: sentence, QID: bb8ec96afe02ce454a1a80976450b055, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: The researcher cut his hand and went to the sink, where was the researcher?
# Options:
# A. home
# B. chemistry lab
# C. apartment
# D. laboratory
# E. laundry room
# Context:
# sink → wet work → terminate with extreme prejudice → extreme prejudice → hostility → amity → hostility → amity → hostility → amity → hostility
# GPT Answer: D
# Mapped to: laboratory
# Correct: laboratory
# Reward: 1
#
# 📚 [275] Template: summary, QID: 72605fb21b4f3bca1edb54da86432c3e, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: What does hitting the side of a horse cause?
# Options:
# A. movement
# B. fear
# C. stiffness
# D. running
# E. bouncing
# Summary:
# The concept 'riding horse' leads through 11 steps to 'motivate'
# GPT Answer: A
# Mapped to: movement
# Correct: movement
# Reward: 1
#
# 📚 [276] Template: sentence, QID: ed069d8878c9d355c7a6d1daec1cffc6, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: What can some day be combined to form?
# Options:
# A. hackday
# B. morning
# C. twenty four
# D. week
# E. night
# Context:
# day → bright → encouraging → encourage → discourage → encourage → discourage → encourage → discourage → encourage → discourage
# GPT Answer: D
# Mapped to: week
# Correct: week
# Reward: 1
#
# 📚 [277] Template: summary, QID: 866deeda79fe257ffcfc08c674962894, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: A snake is not something you want to come across on a plane, but it's most likely to happen while out in mother what?
# Options:
# A. nature
# B. pet shop
# C. georgia
# D. tropical forest
# E. france
# Summary:
# The concept 'snake' leads through 11 steps to 'limit'
# GPT Answer: A
# Mapped to: nature
# Correct: nature
# Reward: 1
#
# 📚 [278] Template: sentence, QID: 545f683374a3b6c8d8b1ec29ea30e3e4, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Which state is the blue ridge mountains roanoke city in?
# Options:
# A. appalachians
# B. north carolina
# C. virginia
# D. pennsylvania
# E. montana
# Context:
# blue ridge mountains → virginia
# GPT Answer: C
# Mapped to: virginia
# Correct: virginia
# Reward: 1
#
# 📚 [279] Template: summary, QID: d2f7e9a66705c428d2bfa8de8b6755bc, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: James took the junk off of the place where he sleeps and threw it into what?
# Options:
# A. attic
# B. garage
# C. bed
# D. drawer
# E. television
# Summary:
# The concept 'junk' leads through 11 steps to 'city limits'
# GPT Answer: B
# Mapped to: garage
# Correct: drawer
# Reward: 0
#
# 📚 [280] Template: sentence, QID: f182135ff39a2ed76722e814ceb227fa, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: When she went to examine the thing, what was she considering doing with it?
# Options:
# A. eat cake
# B. buy
# C. interests
# D. complex
# E. learn about
# Context:
# examine thing → pick up → hang up → pick up → hang up → pick up → hang up → pick up → hang up → pick up → hang up
# GPT Answer: B
# Mapped to: buy
# Correct: buy
# Reward: 1
#
# 📚 [281] Template: sentence, QID: deb397b9511dd44f7d2d3e1a713921b5, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: If you're getting drunk while in public you are likely where?
# Options:
# A. jail
# B. gutter
# C. city hall
# D. park
# E. bar
# Context:
# drunk → raise hell → raise hell → raise hell → raise hell → raise hell → raise hell → raise hell → raise hell → raise hell → raise hell
# GPT Answer: E
# Mapped to: bar
# Correct: bar
# Reward: 1
#
# 📚 [282] Template: sentence, QID: ad6e205e2109fe9d4f2c5f03d2bf6223, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: She wanted to donate her old clothes to charity, she began folding and stacking the clothing into a what?
# Options:
# A. box
# B. basement
# C. trash
# D. bag
# E. trunk
# Context:
# old clothes → box
# GPT Answer: A
# Mapped to: box
# Correct: box
# Reward: 1
#
# 📚 [283] Template: triples, QID: f1586b47f1f3131f6ca837fdac0fff05, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: What kind of entertainment may feature a talking weasel on an adventure?
# Options:
# A. children's story
# B. forrest
# C. mulberry bush
# D. animated film
# E. outdoors
# Knowledge:
# (weasel → animated film)
# GPT Answer: D
# Mapped to: animated film
# Correct: animated film
# Reward: 1
#
# 📚 [284] Template: sentence, QID: 8aef49cac285a9373b64b6e1d6bf7595, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: News and reality shows are examples of programs that are not works of what?
# Options:
# A. fiction
# B. old information
# C. fun
# D. documentary
# E. propaganda
# Context:
# news → relevant → irrelevant → relevant → irrelevant → relevant → irrelevant → relevant → irrelevant → relevant → irrelevant
# GPT Answer: A
# Mapped to: fiction
# Correct: fiction
# Reward: 1
#
# 📚 [285] Template: sentence, QID: ec05fe1917b3a94d8d86892b2d0f7717, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: If you pour out garbage waste on the road to where will it wash away?
# Options:
# A. sewer
# B. garbage dump
# C. street
# D. garbage can
# E. school
# Context:
# garbage waste → unwanted → want → poverty → undesirable → desirable → undesirable → desirable → undesirable → desirable → undesirable
# GPT Answer: A
# Mapped to: sewer
# Correct: sewer
# Reward: 1
#
# 📚 [286] Template: sentence, QID: 0b883988a317a09f784c1e15dfe591ad, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: What is on the base of a stack of cubes?
# Options:
# A. transistor
# B. home plate
# C. floor
# D. box
# E. vessel
# Context:
# base → box
# GPT Answer: D
# Mapped to: box
# Correct: box
# Reward: 1
#
# 📚 [287] Template: triples, QID: 748842cda8d355f5511d23d7f7a7bb67, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Where can peanut butter be stored?
# Options:
# A. container
# B. supermarket
# C. pantry
# D. sandwich
# E. jar
# Knowledge:
# (peanut butter → sticky)
# (sticky → adhesive)
# (adhesive → adhesion)
# (adhesion → adhesive)
# (adhesive → adhesion)
# (adhesion → adhesive)
# (adhesive → adhesion)
# (adhesion → adhesive)
# (adhesive → adhesion)
# (adhesion → adhesive)
# GPT Answer: C
# Mapped to: pantry
# Correct: pantry
# Reward: 1
#
# 📚 [288] Template: summary, QID: 834d3c1c38698de9468b771d88acfb0f, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: The coach explained respect to the players before the game against the worst team in the league, he didn't want his players to what to the opponents?
# Options:
# A. belittle
# B. contemn
# C. diss
# D. castrate
# E. disregard
# Summary:
# The concept 'respect' leads through 11 steps to 'scorn'
# GPT Answer: B
# Mapped to: contemn
# Correct: belittle
# Reward: 0
#
# 📚 [289] Template: summary, QID: 1a04ff6393bb28f6d5fa710286e8cd26, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: The stack of dirty dishes was quite high, it was definitely time to what?
# Options:
# A. clean
# B. ground
# C. bright
# D. sportsmanlike
# E. bed
# Summary:
# The concept 'dirty' leads through 11 steps to 'prohibit'
# GPT Answer: A
# Mapped to: clean
# Correct: clean
# Reward: 1
#
# 📚 [290] Template: sentence, QID: 90c7fef95d764ed617c1a688999c6276, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: James didn't know what to do.  He felt that he'd ruin his relationship with Jen if he took it further, and he didn't want to do that.  At the same time,  He fight that pushing farther might do what to something good?
# Options:
# A. found
# B. destroy
# C. construct
# D. fix
# E. produce
# Context:
# ruin → produce
# GPT Answer: B
# Mapped to: destroy
# Correct: produce
# Reward: 0
#
# 📚 [291] Template: summary, QID: a8de45d4f30e74f541d883ba83b02898, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Where are mine's typically located under?
# Options:
# A. pennsylvania
# B. desert
# C. valley
# D. cambodia
# E. mountain
# Summary:
# The concept 'mine' leads through 11 steps to 'east timor'
# GPT Answer: E
# Mapped to: mountain
# Correct: mountain
# Reward: 1
#
# 📚 [292] Template: summary, QID: e6d99b4b76f74961a400ad0001b13b73, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Which entrance would you use if you do not want to use the back entrance?
# Options:
# A. side
# B. main
# C. anterior
# D. current
# E. front
# Summary:
# The concept 'back' leads through 11 steps to 'gain'
# GPT Answer: E
# Mapped to: front
# Correct: main
# Reward: 0
#
# 📚 [293] Template: summary, QID: 50dabad382ac02b6b79b2ef9ed7c43fd, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Someone who's belief in a philosophy is not slight but extreme is what?
# Options:
# A. significant
# B. important
# C. radical
# D. radical
# E. essencial
# Summary:
# The concept 'slight' leads through 11 steps to 'negligible'
# GPT Answer: C
# Mapped to: radical
# Correct: radical
# Reward: 1
#
# 📚 [294] Template: sentence, QID: a7258c8b696b621464f3abd5cd666ea2, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Where would most people store their fortune?
# Options:
# A. imagination
# B. bank
# C. cookie
# D. treasure chest
# E. gold
# Context:
# fortune → poverty → undesirable → desirable → undesirable → desirable → undesirable → desirable → undesirable → desirable → undesirable
# GPT Answer: B
# Mapped to: bank
# Correct: bank
# Reward: 1
#
# 📚 [295] Template: triples, QID: 349f048d055eced792dfba61b1d204a7, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: What will happen to you if your need is met?
# Options:
# A. unhappy
# B. sufficient
# C. wants
# D. satisfied
# E. unnecessary
# Knowledge:
# (need → poverty)
# (poverty → undesirable)
# (undesirable → desirable)
# (desirable → undesirable)
# (undesirable → desirable)
# (desirable → undesirable)
# (undesirable → desirable)
# (desirable → undesirable)
# (undesirable → desirable)
# (desirable → undesirable)
# GPT Answer: D
# Mapped to: satisfied
# Correct: satisfied
# Reward: 1
#
# 📚 [296] Template: sentence, QID: bdb7ca0e3c8d2e9cb315c0479300f4f9, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: You can pick more than one number, or even pick a color on the what?
# Options:
# A. telephone book
# B. mathematics
# C. telephone
# D. roulette wheel
# E. math problem
# Context:
# number → equation → inequality → less → greater → lesser → greater → lesser → greater → lesser → greater
# GPT Answer: D
# Mapped to: roulette wheel
# Correct: roulette wheel
# Reward: 1
#
# 📚 [297] Template: triples, QID: 609379b5cd23ae006b6ef29a8fb9ae88, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: What in a car could have an led?
# Options:
# A. electronics
# B. dashboard
# C. electronic equipment
# D. display
# E. pc board
# Knowledge:
# (led → pc board)
# (pc board → circuit board)
# (circuit board → circuit)
# (circuit → counties)
# (counties → county)
# (county → state)
# (state → land area)
# (land area → acreage)
# (acreage → area)
# (area → enclosed land)
# GPT Answer: E
# Mapped to: pc board
# Correct: dashboard
# Reward: 0
#
# 📚 [298] Template: sentence, QID: dce47167b8dab9cf3ef1834e2b1e88dd, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: If the though of performing makes you anxious what do you suffer from?
# Options:
# A. being appreciated
# B. get attention
# C. terror
# D. stage fright
# E. fear
# Context:
# performing → self confidence → assurance → assurance → assure → guarantee → pledge → assurance → assure → guarantee → pledge
# GPT Answer: D
# Mapped to: stage fright
# Correct: stage fright
# Reward: 1
#
# 📚 [299] Template: triples, QID: 0c84042e7a2b476d6099a779df7899ae, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Where would you find people who aren't related by blood calling each other brother?
# Options:
# A. family ceremony
# B. home
# C. house
# D. monastery
# E. seminary
# Knowledge:
# (brother → protect)
# (protect → endanger)
# (endanger → threaten)
# (threaten → warn)
# (warn → advise)
# (advise → counsel)
# (counsel → advice)
# (advice → advise)
# (advise → counsel)
# (counsel → advice)
# GPT Answer: D
# Mapped to: monastery
# Correct: seminary
# Reward: 0
#
# 📚 [300] Template: sentence, QID: c8f1a475a007478cabfc58bf83d7d81d, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: She had taken her ring from her finger and placed it on the windowsill so she wouldn't get it wet while she was in what?
# Options:
# A. bath tub
# B. finger
# C. windowsill
# D. wedding ceremony
# E. a coma
# Context:
# ring → engage → disengage → engage → disengage → engage → disengage → engage → disengage → engage → disengage
# GPT Answer: A
# Mapped to: bath tub
# Correct: bath tub
# Reward: 1
#
# 📚 [301] Template: triples, QID: abbbf8bef84d5348c8d3250e59bef7e4, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: The measurement was important and they had to make a, what kind of increase, to get it just right?
# Options:
# A. mighty
# B. slight
# C. negligible
# D. useless
# E. petty
# Knowledge:
# (important → useless)
# (useless → good for nothing)
# (good for nothing → ne er do well)
# (ne er do well → good for nothing)
# (good for nothing → ne er do well)
# (ne er do well → good for nothing)
# (good for nothing → ne er do well)
# (ne er do well → good for nothing)
# (good for nothing → ne er do well)
# (ne er do well → good for nothing)
# GPT Answer: B
# Mapped to: slight
# Correct: slight
# Reward: 1
#
# 📚 [302] Template: sentence, QID: 7ecff79109f499a28c77af4014e513e2, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: There was a fast food restaurant every 200 feet to help handle the foot traffic, what is this characteristic of in general?
# Options:
# A. new york
# B. big cities
# C. center of town
# D. farms
# E. america
# Context:
# fast food restaurant → populated area → urban area → urban area → urban area → urban area → urban area → urban area → highly polluted region → finite spatial thing → spatial thing
# GPT Answer: B
# Mapped to: big cities
# Correct: big cities
# Reward: 1
#
# 📚 [303] Template: triples, QID: 882cd6096c3a64f80fd314268b2fe88f, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Where are you likely to take peanut butter out of?
# Options:
# A. cupboard
# B. supermarket
# C. jar
# D. container
# E. pantry
# Knowledge:
# (peanut butter → sticky)
# (sticky → adhesive)
# (adhesive → adhesion)
# (adhesion → adhesive)
# (adhesive → adhesion)
# (adhesion → adhesive)
# (adhesive → adhesion)
# (adhesion → adhesive)
# (adhesive → adhesion)
# (adhesion → adhesive)
# GPT Answer: C
# Mapped to: jar
# Correct: jar
# Reward: 1
#
# 📚 [304] Template: sentence, QID: 9844957d90fff5abf52ffc02d6b3a382, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: The battleship fleet had all sorts of ships, the small one was called a what?
# Options:
# A. submarine
# B. corvette
# C. destroyer
# D. gambit
# E. frigate
# Context:
# battleship → guessing game → guessing → estimate → estimation → estimate → estimation → estimate → estimation → estimate → estimation
# GPT Answer: C
# Mapped to: destroyer
# Correct: frigate
# Reward: 0
#
# 📚 [305] Template: sentence, QID: bf791147892f89b38a4744cd81ee06a2, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Someone who is selfish wouldn't share a sandwich with their hungry friend, someone who is what might though?
# Options:
# A. philanthropic
# B. unselfish
# C. selfless
# D. altruistic
# E. not hungry
# Context:
# selfish → altruistic → selfish → altruistic → selfish → altruistic → selfish → altruistic → selfish → altruistic → selfish
# GPT Answer: D
# Mapped to: altruistic
# Correct: selfless
# Reward: 0
#
# 📚 [306] Template: triples, QID: 91e0aa69126bc6eadbae8555e39d8577, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: The fat man wanted to make a change in his life and make sure it stayed what?
# Options:
# A. concretely
# B. permanent
# C. remain stable
# D. stagnant
# E. constant
# Knowledge:
# (change → unpleasant)
# (unpleasant → pleasant)
# (pleasant → unpleasant)
# (unpleasant → pleasant)
# (pleasant → unpleasant)
# (unpleasant → pleasant)
# (pleasant → unpleasant)
# (unpleasant → pleasant)
# (pleasant → unpleasant)
# (unpleasant → pleasant)
# GPT Answer: B
# Mapped to: permanent
# Correct: permanent
# Reward: 1
#
# 📚 [307] Template: triples, QID: 6a2025a47e3a64d73f336ede05a6e828, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: They were going to play at the theater, part way through there was a what?
# Options:
# A. spending money
# B. intermission
# C. being entertained
# D. sleepiness
# E. man of la mancha
# Knowledge:
# (going to play → intermission)
# GPT Answer: B
# Mapped to: intermission
# Correct: intermission
# Reward: 1
#
# 📚 [308] Template: triples, QID: a2677f1a6c6bd5c1f581f5f56744987f, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: The man is drunk what does he do after the bar closes?
# Options:
# A. raise hell
# B. throw up
# C. appear ridiculous
# D. obesity
# E. walk off
# Knowledge:
# (drunk → raise hell)
# (raise hell → raise hell)
# (raise hell → raise hell)
# (raise hell → raise hell)
# (raise hell → raise hell)
# (raise hell → raise hell)
# (raise hell → raise hell)
# (raise hell → raise hell)
# (raise hell → raise hell)
# (raise hell → raise hell)
# GPT Answer: A
# Mapped to: raise hell
# Correct: walk off
# Reward: 0
#
# 📚 [309] Template: triples, QID: af30ea4d62d3a67d3d6fe659da559fd3, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: What would a test be if it is not hard?
# Options:
# A. tricky
# B. agreeable
# C. easy
# D. bearable
# E. tryhard
# Knowledge:
# (hard → controvertible)
# (controvertible → incontrovertible)
# (incontrovertible → controvertible)
# (controvertible → incontrovertible)
# (incontrovertible → controvertible)
# (controvertible → incontrovertible)
# (incontrovertible → controvertible)
# (controvertible → incontrovertible)
# (incontrovertible → controvertible)
# (controvertible → incontrovertible)
# GPT Answer: C
# Mapped to: easy
# Correct: easy
# Reward: 1
#
# 📚 [310] Template: sentence, QID: 574e1a4d66d60c9e958f059322c4d6ac, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Where would you put a washcloth to clean it?
# Options:
# A. bed bath store
# B. linen closet
# C. walmart
# D. bathroom sink
# E. closet
# Context:
# washcloth → bathroom sink
# GPT Answer: D
# Mapped to: bathroom sink
# Correct: bathroom sink
# Reward: 1
#
# 📚 [311] Template: sentence, QID: 32944ad66e5136cbf28542864ae61d1f, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: John plays chess with his roommate They make one move each between classes.  Where is his chess set most likely set up?
# Options:
# A. canada
# B. cupboard
# C. dorm
# D. sitting room
# E. drawer
# Context:
# chess set → coffee house → business location → physical contact location → abstract theoretical destination point → enduring thing localized → non situational spatial thing → non situational spatial thing → non situational spatial thing → non situational spatial thing → non situational spatial thing
# GPT Answer: C
# Mapped to: dorm
# Correct: dorm
# Reward: 1
#
# 📚 [312] Template: sentence, QID: af30ea4d62d3a67d3d6fe659da559fd3, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: What would a test be if it is not hard?
# Options:
# A. tricky
# B. agreeable
# C. easy
# D. bearable
# E. tryhard
# Context:
# hard → controvertible → incontrovertible → controvertible → incontrovertible → controvertible → incontrovertible → controvertible → incontrovertible → controvertible → incontrovertible
# GPT Answer: C
# Mapped to: easy
# Correct: easy
# Reward: 1
#
# 📚 [313] Template: summary, QID: 7ef8b91a23171e190005dc5e50307733, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Where does litter land when you throw it away?
# Options:
# A. street corner
# B. midair
# C. ground
# D. bus
# E. roadsides
# Summary:
# The concept 'litter' leads through 2 steps to 'ground'
# GPT Answer: C
# Mapped to: ground
# Correct: ground
# Reward: 1
#
# 📚 [314] Template: triples, QID: a7f1c0c77fa3ab7fc2e70ae4c7fdd65c, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: A significant even in someone's life is something that is not what?
# Options:
# A. ignorable
# B. insignificant
# C. saint
# D. negligible
# E. slight
# Knowledge:
# (significant → negligible)
# (negligible → significant)
# (significant → negligible)
# (negligible → significant)
# (significant → negligible)
# (negligible → significant)
# (significant → negligible)
# (negligible → significant)
# (significant → negligible)
# (negligible → significant)
# GPT Answer: C
# Mapped to: saint
# Correct: ignorable
# Reward: 0
#
# 📚 [315] Template: triples, QID: e39af43324809c222f031d4d2ee513a0, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: He used hair styling gel, he kept it where?
# Options:
# A. tube
# B. outside
# C. store
# D. bathroom
# E. refrigerator
# Knowledge:
# (gel → bathroom)
# GPT Answer: D
# Mapped to: bathroom
# Correct: bathroom
# Reward: 1
#
# 📚 [316] Template: sentence, QID: ea112d5d5d7c4e4a98b01cd246bf42e4, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: James was a stranger to them, but to me he was what?
# Options:
# A. friend
# B. family
# C. park
# D. known person
# E. yellow
# Context:
# stranger → fearsome → fear → motivate → demotivate → motivate → demotivate → motivate → demotivate → motivate → demotivate
# GPT Answer: B
# Mapped to: family
# Correct: friend
# Reward: 0
#
# 📚 [317] Template: summary, QID: ff83f66bc1e5a772cc67d80db035b023, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: She found the trend quite odd, but it seemed that this was the new what?
# Options:
# A. even
# B. common
# C. regular
# D. normal
# E. thing to do
# Summary:
# The concept 'odd' leads through 11 steps to 'restrict'
# GPT Answer: D
# Mapped to: normal
# Correct: normal
# Reward: 1
#
# 📚 [318] Template: summary, QID: a8924790901bc93eb94d6e7bf360b5e0, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: While he had great disdain for the King and his knights he still respected their what?
# Options:
# A. reverence
# B. respect
# C. honor
# D. admiration
# E. kindness
# Summary:
# The concept 'disdain' leads through 11 steps to 'disdain'
# GPT Answer: C
# Mapped to: honor
# Correct: honor
# Reward: 1
#
# 📚 [319] Template: summary, QID: 657084f4b6c6a25a20cd45905fb9e682, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: What form of government is most associated with kingdoms?
# Options:
# A. monarchy
# B. ruled by government
# C. europe
# D. book
# E. king
# Summary:
# The concept 'kingdom' leads through 11 steps to 'westwards'
# GPT Answer: A
# Mapped to: monarchy
# Correct: monarchy
# Reward: 1
#
# 📚 [320] Template: summary, QID: 7b355025e2bb5f271e423cfc9348141b, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: While up in the mountains the locals taught him all the tricks of the fingerboard, he learned the basics of playing the what?
# Options:
# A. violin
# B. banjo
# C. mandolin
# D. guitar
# E. lute
# Summary:
# The concept 'fingerboard' leads through 2 steps to 'banjo'
# GPT Answer: B
# Mapped to: banjo
# Correct: banjo
# Reward: 1
#
# 📚 [321] Template: sentence, QID: 1ee87a70f0646c18e61b9d6641f05a42, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Video games can be quite fun and entertaining, but some are actual good for kids and what?
# Options:
# A. fun to play
# B. played inside stadium
# C. played at office
# D. educational
# E. played outside
# Context:
# games → educational
# GPT Answer: D
# Mapped to: educational
# Correct: educational
# Reward: 1
#
# 📚 [322] Template: sentence, QID: 13563b8cdf850dc6b1a7b8062d23b710, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Broom stood in the middle of the room.  There were two doors on opposite sides of him, but he couldn't see them.  Where were they?
# Options:
# A. large small
# B. extremes
# C. left right
# D. invisible
# E. front back
# Context:
# middle → extremes → extreme → moderate → decrease → gain → reduce → gain weight → obese → body mass index → underweight
# GPT Answer: B
# Mapped to: extremes
# Correct: left right
# Reward: 0
#
# 📚 [323] Template: triples, QID: fa6f196ed3eb1df0abee8049750821a8, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: The living do many things that the dead do not, but one is most important.  What do the living do that the dead do not?
# Options:
# A. talk
# B. sometimes bad
# C. pollution
# D. happiness
# E. have experiences
# Knowledge:
# (living → palpitations)
# (palpitations → palpitation)
# (palpitation → palpitate)
# (palpitate → quiver)
# (quiver → vibration)
# (vibration → equilibrium)
# (equilibrium → disequilibrium)
# (disequilibrium → equilibrium)
# (equilibrium → disequilibrium)
# (disequilibrium → equilibrium)
# GPT Answer: E
# Mapped to: have experiences
# Correct: have experiences
# Reward: 1
#
# 📚 [324] Template: sentence, QID: eff865a55bff055dc740f6217fbc512b, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Someone who doesn't believe in the divine could be called what?
# Options:
# A. godless
# B. humdrum
# C. godless
# D. horrible
# E. undivine
# Context:
# divine → godless
# GPT Answer: A
# Mapped to: godless
# Correct: godless
# Reward: 1
#
# 📚 [325] Template: triples, QID: 59a6da5e7cc379860a2cd1e01d4e8384, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: The person was bad, but everything he said was what?
# Options:
# A. just
# B. sufficient
# C. true
# D. badarse
# E. prime
# Knowledge:
# (bad → competent)
# (competent → incompetent)
# (incompetent → competent)
# (competent → incompetent)
# (incompetent → competent)
# (competent → incompetent)
# (incompetent → competent)
# (competent → incompetent)
# (incompetent → competent)
# (competent → incompetent)
# GPT Answer: C
# Mapped to: true
# Correct: true
# Reward: 1
#
# 📚 [326] Template: summary, QID: 6e982b31a550b2758535d871ff3326ed, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: The priest pushed for more orthodox behavior, what kind of behavior was he trying to stop?
# Options:
# A. liberal
# B. heretical
# C. recalcitrant
# D. conservadox
# E. heretical
# Summary:
# The concept 'orthodox' leads through 11 steps to 'adhesion'
# GPT Answer: B
# Mapped to: heretical
# Correct: heretical
# Reward: 1
#
# 📚 [327] Template: summary, QID: b6211948a2f817e66425b971d9f8325f, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Sunshine and warmth are the weathers associated with what?
# Options:
# A. alaska
# B. summer
# C. disneyland
# D. beach
# E. meadow
# Summary:
# The concept 'sunshine' leads through 11 steps to 'disadvantage'
# GPT Answer: B
# Mapped to: summer
# Correct: summer
# Reward: 1
#
# 📚 [328] Template: summary, QID: 0ef10c521bb62ad2fe2d14304274dd8e, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: The recipe called for much salt to really bring out the flavor, but given his dietary restrictions he added just a what?
# Options:
# A. too much
# B. little bit
# C. too little
# D. too few
# E. very little
# Summary:
# The concept 'much' leads through 11 steps to 'greater'
# GPT Answer: B
# Mapped to: little bit
# Correct: little bit
# Reward: 1
#
# 📚 [329] Template: sentence, QID: f5111698f5e9795613d340dccde1e40c, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: The two parties could neither confirm nor compromise on anything, they were in a what?
# Options:
# A. question
# B. contradict
# C. deny
# D. asking
# E. dispute
# Context:
# confirm → infirm → decrepit → flea bitten → decrepit → flea bitten → decrepit → flea bitten → decrepit → flea bitten → decrepit
# GPT Answer: E
# Mapped to: dispute
# Correct: dispute
# Reward: 1
#
# 📚 [330] Template: sentence, QID: 84639f7f0f7b5d7c4584c76e2a6e9f8b, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: He didn't want his son to be soft, so he was always what on him?
# Options:
# A. hard
# B. sandpaper
# C. loud
# D. firm
# E. abrasive
# Context:
# soft → harsh → rigorous → capricious → rigorous → capricious → rigorous → capricious → rigorous → capricious → rigorous
# GPT Answer: A
# Mapped to: hard
# Correct: hard
# Reward: 1
#
# 📚 [331] Template: triples, QID: f5d2db88101a900319fd872a9af8c746, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: By the end of one field the sharp scythe wasn't cutting because it had become what?
# Options:
# A. blunt
# B. ocean
# C. flat
# D. unobservant
# E. dim
# Knowledge:
# (sharp → above board)
# (above board → above)
# (above → below)
# (below → above)
# (above → below)
# (below → above)
# (above → below)
# (below → above)
# (above → below)
# (below → above)
# GPT Answer: A
# Mapped to: blunt
# Correct: blunt
# Reward: 1
#
# 📚 [332] Template: triples, QID: 6435a28a5d2eca7131dd5dc029cc485e_1, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: If one needed peas and shopped local, where might they go?
# Options:
# A. supermarket
# B. fridge
# C. grocery store
# D. farmer's market
# E. freezer
# Knowledge:
# (peas → farmer's market)
# GPT Answer: D
# Mapped to: farmer's market
# Correct: farmer's market
# Reward: 1
#
# 📚 [333] Template: summary, QID: 676ba4640e14ea96964082dda5672940, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: What kind of person would believe in God and kill a divine entity?
# Options:
# A. undivine
# B. godless
# C. wonderful
# D. humdrum
# E. horrible
# Summary:
# The concept 'divine' leads through 2 steps to 'horrible'
# GPT Answer: E
# Mapped to: horrible
# Correct: horrible
# Reward: 1
#
# 📚 [334] Template: sentence, QID: d1aa0ed347fdd1bdda24c9399fabeadd, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: He hadn't paid the tax or many other bills for that matter, he had horrible what?
# Options:
# A. credit
# B. income
# C. manual
# D. free money
# E. refund
# Context:
# tax → rebate → discount → surcharge → discount → surcharge → discount → surcharge → discount → surcharge → discount
# GPT Answer: A
# Mapped to: credit
# Correct: credit
# Reward: 1
#
# 📚 [335] Template: summary, QID: 2668621aab1626c2ea0523a5477d815f, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: He was bound for llano estacado, where was his end goal?
# Options:
# A. oklahoma
# B. new mexico
# C. texas
# D. mexico
# E. great plains
# Summary:
# The concept 'llano estacado' leads through 2 steps to 'new mexico'
# GPT Answer: B
# Mapped to: new mexico
# Correct: new mexico
# Reward: 1
#
# 📚 [336] Template: summary, QID: 10eeb43da5af757483ec29f01e563ae8, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: What will happen to your clothes if you are full?
# Options:
# A. topfull
# B. incomplete
# C. enlarge
# D. close fitting
# E. partial
# Summary:
# The concept 'full' leads through 11 steps to 'evacuate'
# GPT Answer: C
# Mapped to: enlarge
# Correct: close fitting
# Reward: 0
#
# 📚 [337] Template: summary, QID: 8d87db96a87432ee5f01d24326b121b5, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Where is a flat likely to be grouped with other flats?
# Options:
# A. london
# B. city
# C. town
# D. apartment building
# E. condominium
# Summary:
# The concept 'flat' leads through 11 steps to 'heel'
# GPT Answer: D
# Mapped to: apartment building
# Correct: apartment building
# Reward: 1
#
# 📚 [338] Template: summary, QID: fb3a63a5171e8f791963b8554c80b45f, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: When someone doesn't have beauty they have?
# Options:
# A. ugly
# B. beast
# C. waterfall
# D. waterfall
# E. ugliness
# Summary:
# The concept 'beauty' leads through 11 steps to 'repulsive'
# GPT Answer: E
# Mapped to: ugliness
# Correct: ugliness
# Reward: 1
#
# 📚 [339] Template: triples, QID: 28a39911316dd9386ee6bb8b3c3926df, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Where could you find millions of jellyfish?
# Options:
# A. north sea
# B. smack
# C. sponge bob's house
# D. store
# E. sea water
# Knowledge:
# (jellyfish → chesapeake bay)
# (chesapeake bay → virginia)
# (virginia → administrative region)
# (administrative region → federal district)
# (federal district → territory)
# (territory → district)
# (district → city limits)
# (city limits → city limit)
# (city limit → town)
# (town → rural areas)
# GPT Answer: E
# Mapped to: sea water
# Correct: north sea
# Reward: 0
#
# 📚 [340] Template: triples, QID: 193ba63fa8b62223da31ef8ec68da5bf, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: The small locally owned beauty salon had it's grand opening, people hoped it would boost the economy in the surrounding what?
# Options:
# A. clerk
# B. barber shop
# C. neighborhood
# D. city
# E. strip mall
# Knowledge:
# (beauty salon → neighborhood)
# GPT Answer: C
# Mapped to: neighborhood
# Correct: neighborhood
# Reward: 1
#
# 📚 [341] Template: sentence, QID: d6503fc1f87e3e2caeb7bf8e16526e0f, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: James felt himself losing consciousness.  He was frightened.  He didn't want this.  He was scared of what?
# Options:
# A. death
# B. coma
# C. peace
# D. forgetfulness
# E. loss of life
# Context:
# losing consciousness → panic → system → retrieve → retrieval → device → show → indicate → inform → change → cost
# GPT Answer: A
# Mapped to: death
# Correct: death
# Reward: 1
#
# 📚 [342] Template: triples, QID: 975bd11690377b83af5d3a47bd1c9aec, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: If an area is not thick with resource, those resources are what?
# Options:
# A. free flowing
# B. translucent
# C. sparse
# D. slender
# E. clear
# Knowledge:
# (thick → slim)
# (slim → reduce)
# (reduce → gain)
# (gain → reduce)
# (reduce → gain)
# (gain → reduce)
# (reduce → gain)
# (gain → reduce)
# (reduce → gain)
# (gain → reduce)
# GPT Answer: C
# Mapped to: sparse
# Correct: sparse
# Reward: 1
#
# 📚 [343] Template: sentence, QID: 7893a5e4b162c221eabefdeabdd7e9ad, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: John looked for shade but couldn't find any. Where might be be?
# Options:
# A. sunny place
# B. summer
# C. direct sunlight
# D. bright sunshine
# E. full sunlight
# Context:
# shade → protections → protection → economics → dismal science → political economy → political science → public policy → political science → public policy → political science
# GPT Answer: C
# Mapped to: direct sunlight
# Correct: sunny place
# Reward: 0
#
# 📚 [344] Template: summary, QID: 37087b542cc140905626a5260d38d87a, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: The view was sharp in front of the flashlight after changing batteries, what was it like before?
# Options:
# A. dim
# B. inaccurate
# C. above board
# D. blunt
# E. flat
# Summary:
# The concept 'sharp' leads through 11 steps to 'above'
# GPT Answer: A
# Mapped to: dim
# Correct: dim
# Reward: 1
#
# 📚 [345] Template: summary, QID: 76d3d3343a9491c3983211539b3e716e, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: What country is arkansas in?
# Options:
# A. colorado
# B. mexico
# C. arkansas
# D. united states
# E. oklahoma
# Summary:
# The concept 'arkansas' leads through 2 steps to 'united states'
# GPT Answer: D
# Mapped to: united states
# Correct: united states
# Reward: 1
#
# 📚 [346] Template: sentence, QID: 84639f7f0f7b5d7c4584c76e2a6e9f8b, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: He didn't want his son to be soft, so he was always what on him?
# Options:
# A. hard
# B. sandpaper
# C. loud
# D. firm
# E. abrasive
# Context:
# soft → harsh → strict → permissive → permission → prohibition → permission → prohibition → permission → prohibition → permission
# GPT Answer: A
# Mapped to: hard
# Correct: hard
# Reward: 1
#
# 📚 [347] Template: sentence, QID: 06f2e444f7aea3db36f75a5f3b436271, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Where would you find a binder containing homework assignments?
# Options:
# A. backpack
# B. bookcase
# C. office supply store
# D. office
# E. class room
# Context:
# binder → make hay → advantage → disadvantage → advantage → disadvantage → advantage → disadvantage → advantage → disadvantage → advantage
# GPT Answer: A
# Mapped to: backpack
# Correct: class room
# Reward: 0
#
# 📚 [348] Template: triples, QID: 1c22d24c80a053c85f2113b10dee981a, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: David was lost but he couldn't remember where he put the map.  He knew that he had it the last time he stopped.  He remembered getting out his toothbrush and brushing, then putting everything up. Where might the map be?
# Options:
# A. atlas
# B. rest area
# C. posession
# D. heaven
# E. suitcase
# Knowledge:
# (map → table)
# (table → floor)
# (floor → table)
# (table → floor)
# (floor → table)
# (table → conference)
# (conference → multilateral)
# (multilateral → politics)
# (politics → wage war)
# (wage war → claim territory)
# GPT Answer: E
# Mapped to: suitcase
# Correct: suitcase
# Reward: 1
#
# 📚 [349] Template: sentence, QID: bcbf38170d3f7cf554e665ee5ebf80d9, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: The guide told them to be very safe in this section, the bears in this are were very what?
# Options:
# A. easily spooked
# B. harmful
# C. precarious
# D. dangerous
# E. in danger
# Context:
# safe → harmful → beneficial → benefit → disadvantage → advantage → disadvantage → advantage → disadvantage → advantage → disadvantage
# GPT Answer: D
# Mapped to: dangerous
# Correct: dangerous
# Reward: 1
#
# 📚 [350] Template: sentence, QID: 0033056483ba6423535f0d693d09c4cf_1, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Where would you put a dictionary while you're using it?
# Options:
# A. library
# B. study area
# C. table
# D. classroom
# E. shelf
# Context:
# dictionary → table
# GPT Answer: C
# Mapped to: table
# Correct: table
# Reward: 1
#
# 📚 [351] Template: triples, QID: d41f1ea45ff85fa3e11c9dc1715712ac, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Where would you find many a bookshelf?
# Options:
# A. bedroom
# B. library
# C. book store
# D. furniture store
# E. ocean
# Knowledge:
# (bookshelf → furniture store)
# (furniture store → retail store)
# (retail store → mercantile establishment)
# (mercantile establishment → place of business)
# (place of business → franchise)
# (franchise → concession)
# (concession → demand)
# (demand → supply)
# (supply → demand)
# (demand → supply)
# GPT Answer: B
# Mapped to: library
# Correct: library
# Reward: 1
#
# 📚 [352] Template: summary, QID: 5f2c5ae4bd5b241f2913f963b6dd7417, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: The living conditions were poor, but the building wasn't condemned as they were still barely what?
# Options:
# A. adequate
# B. poormouth
# C. rich
# D. enough
# E. good
# Summary:
# The concept 'poor' leads through 2 steps to 'adequate'
# GPT Answer: A
# Mapped to: adequate
# Correct: adequate
# Reward: 1
#
# 📚 [353] Template: summary, QID: 7754a0c77dfd57a207da823796f56031, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
# ...
# Options:
# A. refrigerator
# B. carpet
# C. fridge
# D. dishwasher
# E. cellar
# Context:
# mold → carpet
# GPT Answer: B
# Mapped to: carpet
# Correct: carpet
# Reward: 1
#
# 📚 [464] Template: summary, QID: 8f94e2afc2456142d50a8e76bb4f2ba7, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: What's it called when you have seen something through an eyepiece?
# Options:
# A. sights
# B. optical illusion
# C. optical telescope
# D. light microscope
# E. binocular
# Summary:
# The concept 'eyepiece' leads through 11 steps to 'or quarter'
# GPT Answer: A
# Mapped to: sights
# Correct: sights
# Reward: 1
#
# 📚 [465] Template: summary, QID: 25f24bf27c62f862f9d01a86b77dab48, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Billy was a solider.  He joined the military because he wanted to do what?
# Options:
# A. to marry
# B. fight for freedom
# C. report for duty
# D. wait for orders
# E. receive orders
# Summary:
# The concept 'soldier' leads through 11 steps to 'hang up'
# GPT Answer: B
# Mapped to: fight for freedom
# Correct: fight for freedom
# Reward: 1
#
# 📚 [466] Template: sentence, QID: 834d3c1c38698de9468b771d88acfb0f, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: The coach explained respect to the players before the game against the worst team in the league, he didn't want his players to what to the opponents?
# Options:
# A. belittle
# B. contemn
# C. diss
# D. castrate
# E. disregard
# Context:
# respect → contempt → scorn → contempt → scorn → contempt → scorn → contempt → scorn → contempt → scorn
# GPT Answer: A
# Mapped to: belittle
# Correct: belittle
# Reward: 1
#
# 📚 [467] Template: triples, QID: 7659f9fdc67be37beb57ec9463556e0b, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: What kind of building has many a book written in Hebrew?
# Options:
# A. library
# B. classroom
# C. library of congress
# D. suitcase
# E. synagogue
# Knowledge:
# (book → discount store)
# (discount store → discount house)
# (discount house → mercantile establishment)
# (mercantile establishment → place of business)
# (place of business → franchise)
# (franchise → jurisdiction)
# (jurisdiction → geographical region)
# (geographical region → geographical area)
# (geographical area → classification)
# (classification → basic cognitive process)
# GPT Answer: E
# Mapped to: synagogue
# Correct: synagogue
# Reward: 1
#
# 📚 [468] Template: triples, QID: c158a0f0bd7cbd283d6eae94f15b5c19, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Thick molasses isn't what?
# Options:
# A. free flowing
# B. sweet
# C. unacquainted
# D. sparse
# E. slender
# Knowledge:
# (thick → viscous)
# (viscous → viscosity)
# (viscosity → viscous)
# (viscous → viscosity)
# (viscosity → viscous)
# (viscous → viscosity)
# (viscosity → viscous)
# (viscous → viscosity)
# (viscosity → viscous)
# (viscous → viscosity)
# GPT Answer: A
# Mapped to: free flowing
# Correct: free flowing
# Reward: 1
#
# 📚 [469] Template: summary, QID: c5d9cbc34ae24755c5116aa5784a9122, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: What is someone who is bad unlikely to be called?
# Options:
# A. delinquent
# B. exceptional
# C. advantageous
# D. sufficient
# E. virtuous
# Summary:
# The concept 'bad' leads through 11 steps to 'underweight'
# GPT Answer: E
# Mapped to: virtuous
# Correct: virtuous
# Reward: 1
#
# 📚 [470] Template: triples, QID: a5f206a08b3ea4697a4b4cbe6f679dac, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: The alley cats were all beginning to gather together, but one loud crash sent them all what?
# Options:
# A. disburse
# B. charming
# C. scattering
# D. spread
# E. dispense
# Knowledge:
# (gather → lose)
# (lose → gain)
# (gain → reduce)
# (reduce → gain)
# (gain → reduce)
# (reduce → gain)
# (gain → reduce)
# (reduce → gain)
# (gain → reduce)
# (reduce → gain)
# GPT Answer: C
# Mapped to: scattering
# Correct: scattering
# Reward: 1
#
# 📚 [471] Template: summary, QID: 0d860bfecbc530eefa88df34cdfd3354, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Sarah had a sharp mind, but she wasn't social. She was very what?
# Options:
# A. inaccurate
# B. dull
# C. inelegant
# D. complimentary
# E. boring
# Summary:
# The concept 'sharp' leads through 11 steps to 'above'
# GPT Answer: E
# Mapped to: boring
# Correct: inelegant
# Reward: 0
#
# 📚 [472] Template: sentence, QID: 33834441e86dd2b5555474e3cb9c932d, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Where might a tabby cat be most happy?
# Options:
# A. alley
# B. lap
# C. cellar
# D. street
# E. home
# Context:
# tabby cat → home
# GPT Answer: E
# Mapped to: home
# Correct: home
# Reward: 1
#
# 📚 [473] Template: sentence, QID: 84a559081220249df3a27f1f406594f6, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: It was a great rest, she had never felt this much what in the morning?
# Options:
# A. active
# B. hunger
# C. in motion
# D. wakefulness
# E. lay down
# Context:
# rest → recline → decline → decay → decadent → decline → declination → descent → down → mood → scotland
# GPT Answer: D
# Mapped to: wakefulness
# Correct: wakefulness
# Reward: 1
#
# 📚 [474] Template: triples, QID: 456988fd5718cb05c9de270a4a8cbabb, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: The man is drunk and angry, what does he look to do to others?
# Options:
# A. appear ridiculous
# B. fight
# C. throw up
# D. raise hell
# E. walk off
# Knowledge:
# (drunk → raise hell)
# GPT Answer: D
# Mapped to: raise hell
# Correct: raise hell
# Reward: 1
#
# 📚 [475] Template: sentence, QID: 652c6aeafd09881d40b8b2d3abf8b876, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Fresh baked cookies are delicious, it is why they loved to go to Grandma's what?
# Options:
# A. fridge
# B. jar
# C. plate
# D. house
# E. pantry
# Context:
# cookies → edible → inedible → edible → inedible → edible → inedible → edible → inedible → edible → inedible
# GPT Answer: D
# Mapped to: house
# Correct: house
# Reward: 1
#
# 📚 [476] Template: sentence, QID: de89d0191871798a084ed364f7c04f59, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: When making a list what comes after the main item?
# Options:
# A. minor
# B. impossibles
# C. secondary
# D. maintopmast
# E. peripheral
# Context:
# main → secondary
# GPT Answer: C
# Mapped to: secondary
# Correct: secondary
# Reward: 1
#
# 📚 [477] Template: triples, QID: eabf8ce23abc61046ffb6edf6d01129b, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: John is getting something important.  What does this make him feel?
# Options:
# A. then have
# B. headaches
# C. stoic
# D. being happy
# E. wanting more
# Knowledge:
# (getting → let down)
# (let down → disappoint)
# (disappoint → underwhelm)
# (underwhelm → disappoint)
# (disappoint → satisfy)
# (satisfy → convince)
# (convince → assure)
# (assure → guaranty)
# (guaranty → assurance)
# (assurance → certainty)
# GPT Answer: C
# Mapped to: stoic
# Correct: being happy
# Reward: 0
#
# 📚 [478] Template: summary, QID: ed069d8878c9d355c7a6d1daec1cffc6, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: What can some day be combined to form?
# Options:
# A. hackday
# B. morning
# C. twenty four
# D. week
# E. night
# Summary:
# The concept 'day' leads through 11 steps to 'discourage'
# GPT Answer: D
# Mapped to: week
# Correct: week
# Reward: 1
#
# 📚 [479] Template: sentence, QID: ab8d558bb6d24906075ad1167b671578, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: They were competing in basketball, the goal was to what?
# Options:
# A. bounce the ball
# B. competition
# C. have fun
# D. race
# E. score points
# Context:
# competing → bad blood → bad → severe → intense → ultraintense → intense → ultraintense → intense → ultraintense → intense
# GPT Answer: E
# Mapped to: score points
# Correct: score points
# Reward: 1
#
# 📚 [480] Template: triples, QID: 456988fd5718cb05c9de270a4a8cbabb, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: The man is drunk and angry, what does he look to do to others?
# Options:
# A. appear ridiculous
# B. fight
# C. throw up
# D. raise hell
# E. walk off
# Knowledge:
# (drunk → raise hell)
# GPT Answer: D
# Mapped to: raise hell
# Correct: raise hell
# Reward: 1
#
# 📚 [481] Template: summary, QID: 3c7cad0ea62dba0c64595a59e1773470, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: They were trying to explain why the defendant was guilty of obstructing justice, it was their job as the what?
# Options:
# A. riot
# B. choir
# C. prosecution
# D. getting hurt
# E. committing perjury
# Summary:
# The concept 'obstructing justice' leads through 11 steps to 'motivate'
# GPT Answer: C
# Mapped to: prosecution
# Correct: prosecution
# Reward: 1
#
# 📚 [482] Template: summary, QID: 1c304572d38df2e510f3f19a99faa325, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Beautiful lightning strikes happen on what kind of day?
# Options:
# A. november
# B. rainy
# C. dull
# D. wet
# E. average
# Summary:
# The concept 'beautiful' leads through 11 steps to 'disadvantage'
# GPT Answer: B
# Mapped to: rainy
# Correct: rainy
# Reward: 1
#
# 📚 [483] Template: summary, QID: a76f3411fcf94a12e85c872be0804233, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: What does someone want to do fast when they complete something in a perfunctory way?
# Options:
# A. careful
# B. complete
# C. thoughtful
# D. thorough
# E. go on
# Summary:
# The concept 'perfunctory' leads through 11 steps to 'greater'
# GPT Answer: E
# Mapped to: go on
# Correct: complete
# Reward: 0
#
# 📚 [484] Template: summary, QID: ecdd690b72a45c4dfa73fd65939dc9e0, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: She was going to barbecue some kangaroo meat while camping in the outback, where was she?
# Options:
# A. retail store
# B. detroit
# C. wyoming
# D. australia
# E. michigan park
# Summary:
# The concept 'barbecue' leads through 2 steps to 'australia'
# GPT Answer: D
# Mapped to: australia
# Correct: australia
# Reward: 1
#
# 📚 [485] Template: sentence, QID: 748842cda8d355f5511d23d7f7a7bb67, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Where can peanut butter be stored?
# Options:
# A. container
# B. supermarket
# C. pantry
# D. sandwich
# E. jar
# Context:
# peanut butter → sticky → adhesive → adhesion → adhesive → adhesion → adhesive → adhesion → adhesive → adhesion → adhesive
# GPT Answer: C
# Mapped to: pantry
# Correct: pantry
# Reward: 1
#
# 📚 [486] Template: summary, QID: 35468fb940e2f04d13dc2bbe4735548d, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: An expert performing on stage is hoping to do what?
# Options:
# A. explode
# B. stage fright
# C. injury
# D. get attention
# E. being appreciated
# Summary:
# The concept 'performing' leads through 11 steps to 'performance anxiety'
# GPT Answer: E
# Mapped to: being appreciated
# Correct: being appreciated
# Reward: 1
#
# 📚 [487] Template: sentence, QID: 2c4652e60482e27e7c492827e419c717, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Where in a metropolitan area would you likely find a dance club?
# Options:
# A. downtown area
# B. city hall
# C. toun
# D. united states
# E. downtown district
# Context:
# dance club → fun → enjoyable → pleasurable → amusing → unamusing → amusing → unamusing → amusing → unamusing → amusing
# GPT Answer: A
# Mapped to: downtown area
# Correct: downtown area
# Reward: 1
#
# 📚 [488] Template: summary, QID: 98ac4bfbeea35ce9af7820d3d747ebda, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: If song were to touch your heart it would do it through what?
# Options:
# A. smelling
# B. hearing
# C. seeing
# D. sight
# E. sniff
# Summary:
# The concept 'touch' leads through 11 steps to 'deny'
# GPT Answer: B
# Mapped to: hearing
# Correct: hearing
# Reward: 1
#
# 📚 [489] Template: triples, QID: a25544080afadf377e1b07efc2f46d3d, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Where would a restaurant put a candle?
# Options:
# A. dimly lit room
# B. kitchen
# C. wall
# D. table
# E. birthday cake
# Knowledge:
# (candle → table)
# GPT Answer: D
# Mapped to: table
# Correct: table
# Reward: 1
#
# 📚 [490] Template: summary, QID: 5fec231e9937062e30aabca97d2855a4, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: John was told to leave the cheese in the cellar for a few years.  Why is that?
# Options:
# A. strong odor
# B. age well
# C. salad dressing
# D. flavor
# E. age to get better
# Summary:
# The concept 'cheese' leads through 2 steps to 'age to get better'
# GPT Answer: E
# Mapped to: age to get better
# Correct: age to get better
# Reward: 1
#
# 📚 [491] Template: triples, QID: b9859fb27635a6c79aa3c6ad8bec8fe9, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: After work and errands the mother just wanted some peace and quiet, she couldn't wait to just get where?
# Options:
# A. sea
# B. library
# C. driveway
# D. top of mountain
# E. home
# Knowledge:
# (peace and quiet → home)
# GPT Answer: E
# Mapped to: home
# Correct: home
# Reward: 1
#
# 📚 [492] Template: sentence, QID: c49d5239398c4a19ae5e921a76929f61, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: James tripped while running in the house.   His mother had repeatedly warned him to put his toys away but he did not listen. Where might his toys have been?
# Options:
# A. slippery
# B. floor
# C. store
# D. drawer
# E. basement
# Context:
# toys → floor
# GPT Answer: B
# Mapped to: floor
# Correct: floor
# Reward: 1
#
# 📚 [493] Template: sentence, QID: e74b768a33f0f591af80fe4d8ef8f304, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: where can someone get a new chess set?
# Options:
# A. kitchen
# B. toy store
# C. michigan
# D. cupboard
# E. dorm
# Context:
# chess set → toy store
# GPT Answer: B
# Mapped to: toy store
# Correct: toy store
# Reward: 1
#
# 📚 [494] Template: summary, QID: 5f2f50210f84625da678941808a3b3f0, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Upon discovering the remains of the lost city, what did archaeologists try to preserve?
# Options:
# A. use
# B. rot
# C. waste
# D. ruin
# E. decay
# Summary:
# The concept 'preserve' leads through 11 steps to 'engage'
# GPT Answer: D
# Mapped to: ruin
# Correct: ruin
# Reward: 1
#
# 📚 [495] Template: triples, QID: 55e73171cd088d1a41019f076d1d7b10, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Where can you buy lettuce directly from the grower?
# Options:
# A. supermarket
# B. grocery store
# C. salad
# D. farmer's market
# E. refrigerator
# Knowledge:
# (lettuce → farmer's market)
# GPT Answer: D
# Mapped to: farmer's market
# Correct: farmer's market
# Reward: 1
#
# 📚 [496] Template: summary, QID: a6faf89c5a928593dfe95f0a4859c4cf, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: What is the opposite of little?
# Options:
# A. least
# B. much
# C. bog
# D. lot of
# E. big
# Summary:
# The concept 'little' leads through 11 steps to 'lots of'
# GPT Answer: E
# Mapped to: big
# Correct: big
# Reward: 1
#
# 📚 [497] Template: summary, QID: 27fece3289aea6b667d3f2f3402327f8, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: James chose to not to print the cards, because he wanted to be more personal. What type of cards did he choose, instead?
# Options:
# A. cursive writing
# B. hand writing
# C. store bought
# D. online media
# E. hand written
# Summary:
# The concept 'print' leads through 11 steps to 'print'
# GPT Answer: E
# Mapped to: hand written
# Correct: hand written
# Reward: 1
#
# 📚 [498] Template: triples, QID: 0a86e08458102f9c8ab3508e1327cbde, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: Singers go to a studio to do what?
# Options:
# A. clear throats
# B. sound beautiful
# C. warm up
# D. create music
# E. make noise
# Knowledge:
# (singers → show)
# (show → vegas)
# (vegas → s)
# (s → meadow)
# (meadow → countryside)
# (countryside → åland islands)
# (åland islands → european union)
# (european union → brussels)
# (brussels → bruxelles)
# (bruxelles → belgium)
# GPT Answer: D
# Mapped to: create music
# Correct: create music
# Reward: 1
#
# 📚 [499] Template: sentence, QID: b5dcece38a7c1ab91361f111dabee582, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: What is a living thing with a lip?
# Options:
# A. mouth
# B. can
# C. human
# D. snake
# E. kentucky fried chicken
# Context:
# lip → protect → harm → disadvantage → advantage → disadvantage → advantage → disadvantage → advantage → disadvantage → advantage
# GPT Answer: C
# Mapped to: human
# Correct: human
# Reward: 1
#
# 📚 [500] Template: sentence, QID: eb391210101e09f6e685ec90d12189f1, Path len: 1
#
# 🟢 [DEBUG] Sending to GPT...
# Prompt:
#  Question: John's RV needs electricity so that he can cook lunch.  Where would he go to plug in?
# Options:
# A. toy store
# B. basement
# C. school
# D. rest area
# E. building
# Context:
# electricity → opera → theatre → conferences → conference → politics → office → city → state → country → region
# GPT Answer: D
# Mapped to: rest area
# Correct: rest area
# Reward: 1

# %%
mab = PromptConstructorMAB(TEMPLATE_FUNCS)

# %%
print(f"🎯 Accuracy on train set: {acc:.2%}")
# Out:
# 🎯 Accuracy on train set: 83.40%

# %%
import pickle

with open(MAB_TRAIN_PATH, "wb") as f:
    pickle.dump(mab, f)

print(f"✅ MAB saved to {MAB_TRAIN_PATH}")
# Out:
# ✅ MAB saved to /content/drive/MyDrive/ABC/KnowGPT/mab_train_paths_v3.pkl

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# # Thống kê kết quả Train

# %%
print_template_statistics(log)
print_top_prompts(log)
save_log_csv(log)
# Out:
# Template Statistics:
#   sentence: 0.799 (139/174)
#   summary: 0.876 (149/170)
#   triples: 0.827 (129/156)
# --- Top Prompt #1 ---
# Question: Where might a tabby cat be most happy?
# Options:
# A. alley
# B. lap
# C. cellar
# D. street
# E. home
# Context:
# tabby cat → home
# Prediction: E
# Correct: home
#
# --- Top Prompt #2 ---
# Question: Where was there never any mammoth?
# Options:
# A. wild
# B. north dakota
# C. forest
# D. movie
# E. zoo
# Knowledge:
# (mammoth → zoo)
# Prediction: E
# Correct: zoo
#
# --- Top Prompt #3 ---
# Question: Where do you hide a dead body?
# Options:
# A. funeral
# B. closet
# C. container
# D. trunk
# E. basement
# Context:
# dead body → trunk
# Prediction: D
# Correct: trunk
#
# --- Top Prompt #4 ---
# Question: Where do you hide a dead body?
# Options:
# A. funeral
# B. closet
# C. container
# D. trunk
# E. basement
# Context:
# dead body → trunk
# Prediction: D
# Correct: trunk
#
# --- Top Prompt #5 ---
# Question: Using addictive drugs is a bad what?
# Options:
# A. choice
# B. luck
# C. worthy
# D. excellent
# E. upright
# Knowledge:
# (bad → choice)
# Prediction: A
# Correct: choice
#
# ✅ Log saved to mab_eval_log.csv

# %%
import pandas as pd
pd.DataFrame(log).to_csv(RESULT_TRAIN_PATH, index=False)

# %%
import pandas as pd

df = pd.read_csv(RESULT_TRAIN_PATH)

# %%
accuracy_per_template = df.groupby("template")["reward"].mean().sort_values(ascending=False)
print("🎯 Accuracy per template:")
print(accuracy_per_template)
# Out:
# 🎯 Accuracy per template:
# template
# summary     0.876471
# triples     0.826923
# sentence    0.798851
# Name: reward, dtype: float64

# %%
counts = df["template"].value_counts()
print("📊 Sample count per template:")
print(counts)
# Out:
# 📊 Sample count per template:
# template
# sentence    174
# summary     170
# triples     156
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
accuracy_per_template.plot(kind="bar", color="skyblue")
plt.title("Template Accuracy (MAB Evaluation)")
plt.ylabel("Accuracy")
plt.ylim(0, 1.05)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # TEST
